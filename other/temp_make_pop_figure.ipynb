# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.chdir("C:\\code\\activ")

# %%
df_name = 'nov_nine_var.xlsx'

# %%
df = pd.read_excel('./documents/'+df_name).iloc[:,1:23]

# %%
y = df.iloc[:,21:22]

# %%
plt.figure(figsize=(15, 10))
plt.plot(y, linewidth=5, zorder=0)

plt.grid(False)
plt.xticks([0, 48, 96, 144, 192, 240, 288, 336, 384], labels=[1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018])

plt.savefig('./documents/fig/population_graph.png')
plt.show()
