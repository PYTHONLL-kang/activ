# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3436821/3482977643.py in <module>
# ----> 1 import tensorflow as tf
#       2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import os
os.chdir("../../")

# %%
from programs import lstm_tool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3436821/1865601399.py in <module>
# ----> 1 from programs import lstm_tool
#
# ~/dev/kang/activ/programs/lstm_tool.py in <module>
# ----> 1 import tensorflow as tf
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 import random as rand
#       5 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pre_trained_predicter = tf.keras.models.load_model('./model/power_lstm')
compare_predicter = tf.keras.models.load_model('./model/power_lstm')
checker = tf.keras.models.load_model('./model/checker.h5')
# Out:
# 2023-04-21 21:02:21.229050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.229133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.229189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.252238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.252303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.252358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.305479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.305561: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.305619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.457057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.457141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.457198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.472053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.472124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.472180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.503148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.503224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.503285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.517988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.518057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.518113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.542161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.542230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.542286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.556860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.556925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.556980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.571539: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.571606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.571662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.594042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.594116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.594172: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.636991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.637066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.637121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.655982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.656056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.656111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.702216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.702292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.702347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.771201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.771285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.771343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.815723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.815799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.815855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.830469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.830537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.830593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.913586: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.913671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.913727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:21.928744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:21.928814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:21.928869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.046718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.046802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.046858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.144018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.144105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.144161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.158957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.159026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.159080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.181062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.181131: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.181187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.296570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.296661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.296717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.332887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.332962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.333019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.355302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.355373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.355429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.397266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.397342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.397401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.411968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.412036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.412092: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.770668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.770758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.770814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.808010: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.808089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.808145: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.851658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.851732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.851789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.895334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.895412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.895467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.925134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.925206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.925264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:22.939882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:22.939948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:22.940002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.170612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.170701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.170757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.194115: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.194180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.194236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.245986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.246065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.246121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.297719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.297799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.297855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.312893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.312961: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.313016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.343540: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.343619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.343678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:23.358346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:23.358412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:23.358467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# ...
# 2023-04-21 21:02:24.021012: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.021068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.136252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.136337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.136393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.172900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.172975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.173032: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.195087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.195157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.195213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.383242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.383331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.383387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.398234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.398305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.398359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.644513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.644601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.644657: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.681350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.681424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.681479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.725368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.725451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.725507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.768713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.768787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.768842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.798608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.798683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.798740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:24.813402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-21 21:02:24.813469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-21 21:02:24.813524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-21 21:02:25.066942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-21 21:02:25.067742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-21 21:02:25.068337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-21 21:02:25.185306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-21 21:02:25.185975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-21 21:02:25.186558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
df = pd.read_excel('./documents/nov_nine_var.xlsx').iloc[:,1:22].to_numpy()
scaler = MinMaxScaler()
X = scaler.fit_transform(df)

# %%
x, y = lstm_tool.make_sequence(X, 60)

# %%
# 예측 -> 확인
# case 0:
#   train
# case 1:
#   recur

# %%
y[0]
# Out:
# array([0.94736842, 0.19912861, 0.95490972, 0.16190806, 0.34488938,
#        0.30802127, 0.87429939, 0.18766606, 0.49327062, 0.02481508,
#        0.98095238, 0.90225564, 0.42261905, 1.        , 0.46268657,
#        0.9893617 , 0.14629913, 1.        , 0.05292048, 0.06728395,
#        0.07137273])

# %%
pre_trained_predicter(x[0:1])
# Out:
# 2023-04-18 15:10:58.154969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [1,60,21]
# 	 [[{{node inputs}}]]
# <tf.Tensor: shape=(1, 21), dtype=float32, numpy=
# array([[0.9308949 , 0.18855506, 0.9448063 , 0.17493336, 0.33002752,
#         0.30519092, 0.68601096, 0.30046496, 0.6083833 , 0.05815023,
#         0.9870845 , 0.9622651 , 0.42450333, 0.9992107 , 0.4768807 ,
#         0.9879008 , 0.15859592, 0.98999715, 0.07755853, 0.07570504,
#         0.06641897]], dtype=float32)>

# %%
checker([x[0:1], pre_trained_predicter(x[0:1])])
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.83906645]], dtype=float32)>

# %%
x[0:1].shape
# Out:
# (1, 60, 21)

# %%
predict_period = X.shape[0]

# %%
i = 0
inp = x[0:1]

while True:
    with tf.GradientTape() as tape:
        outp = pre_trained_predicter(inp)
        check = checker([inp, outp])

        loss = tf.losses.binary_crossentropy(tf.ones_like(check), check)
    
    t = check[0][0]
    if t < 0.80:
        print(i, t)
        grads = tape.gradient(loss, pre_trained_predicter.trainable_weights)
        pre_trained_predicter.optimizer.apply_gradients(zip(grads, pre_trained_predicter.trainable_weights))
        
        inp = x[0:1]
        i = 0

    else:
        inp = lstm_tool.shift_data(inp, outp)
        i += 1

    if i == predict_period:
        break
# Out:
# 13 tf.Tensor(0.7939718, shape=(), dtype=float32)

# %%
recursive_data = lstm_tool.plot_tree([pre_trained_predicter], x[0:1], 1, predict_period, True)

# %%
compare_data = lstm_tool.plot_tree([compare_predicter], x[0:1], 1, predict_period, True)
plt.plot(lstm_tool.dnn_model(X))
plt.show()
# Out:
# 2023-04-18 15:31:40.599723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [1,60,21]
# 	 [[{{node inputs}}]]

# %%
for i in range(len(compare_data)-61):
    cinp = compare_data[i:i+60].reshape(1, 60, 21)
    coutp = compare_data[i+60+1].reshape(1, 21)
    
    tinp = recursive_data[i:i+60].reshape(1, 60, 21)
    toutp = recursive_data[i+60+1].reshape(1, 21)
    
    a = int(round(checker([tinp, toutp]), 1))
    b = int(round(checker([cinp, coutp]), 1))
    if a != b:
        print(i, " : ", a, b)
