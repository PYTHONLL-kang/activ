# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rand
from sklearn.preprocessing import MinMaxScaler
from collections import deque

# %%
import os
os.chdir('C:\\code\\activ')

# %%
df_name = 'nov_nine_var.xlsx'

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

np.set_printoptions(precision=6, suppress=True)

# %%
dnn_model = tf.keras.models.load_model('./model/dnn.h5')

# %%
# dqn paramater
GAMMA = 0.9
BATCH_SIZE = 1000
SEQUENCE_LENGTH = 12
EPISODE_DONE = 100
EPS_DECAY = 0.99

# %%
df = pd.read_excel('./documents/' + df_name).iloc[:,1::]

scaler = MinMaxScaler()
X = scaler.fit_transform(df.iloc[:,0:21].to_numpy())

starting_state = X[-1].reshape(1, 21)

# %%
def set_goal(goal_df_name):
    """ set goal destination
    Args:
        goal_df_name(str): df_name in documents/result/
    Returns:
        goal_state(ndArray, (1, 21)): the state of lowest rate in df
    """
    goal_df = pd.read_excel('./documents/result/' + goal_df_name).iloc[:,1::].to_numpy()
    index = goal_df[:,-1].argmin()

    goal_state = goal_df[:,0:21][index].reshape(1, 21)
    goal_state = scaler.transform(goal_state)

    return goal_state

# %%
def return_action(i):
    a = np.zeros((1, 21))
    j = i // 2

    if i % 2 == 0:
        a[0][j] = -0.01
    
    else:
        a[0][j] = 0.01
    
    return a

# %%
def return_state(s, a):
    ns = s + a
    return ns

# %%
def return_reward(ns, gs):
    dist = np.sqrt(np.sum(np.square(gs - ns)))
    loss = dist
    
    return -loss

# %%
class DQN_Network(tf.keras.models.Model):
    def __init__(self):
        super(DQN_Network, self).__init__()
        self.input_layer = tf.keras.layers.Dense(128, input_shape=(21, ), activation='relu')

        self.hidden_layer = tf.keras.models.Sequential()
        self.hidden_layer.add(tf.keras.layers.Dense(128, activation='relu'))
        self.hidden_layer.add(tf.keras.layers.Dense(128, activation='relu'))

        self.ouput_layer = tf.keras.layers.Dense(42, activation='linear')

    def call(self, x):
        i = self.input_layer(x)
        h = self.hidden_layer(i)
        o = self.ouput_layer(h)
        return o

# %%
class DQN_Agent:
    def __init__(self):
        self.train_model = self.set_model()
        self.target_model = self.set_model()

        self.memory = deque(maxlen=20000)
        self.episode = 1

        self.optim = tf.keras.optimizers.Adam(learning_rate=1e-10)
        self.loss_fn = tf.keras.losses.MeanSquaredError()

    def set_model(self):
        net = DQN_Network()
        net.build(input_shape=(1, 21))

        optim = tf.keras.optimizers.Adam(learning_rate=1e-10)
        net.compile(optimizer=optim, loss='mse')
        return net

    def memorize(self, cs, a, a_i, r, ns, d):
        if d:
            self.episode += 1
        
        self.memory.append(
            (
                tf.convert_to_tensor(tf.cast(cs, tf.float32)),
                tf.convert_to_tensor(tf.cast(a, tf.float32)),
                a_i,
                tf.convert_to_tensor(tf.cast(r, tf.float32)),
                tf.convert_to_tensor(tf.cast(ns, tf.float32)),
                d
            )
        )

    def convert_memory_to_input(self):
        batch = rand.sample(self.memory, BATCH_SIZE)
        s, a, a_i, r, ns, d = zip(*batch)

        states = tf.convert_to_tensor(s).reshape(BATCH_SIZE, 21)
        actions = tf.convert_to_tensor(a).reshape(BATCH_SIZE, 21)
        action_indexs = tf.convert_to_tensor(a_i)
        rewards = tf.convert_to_tensor(r)
        next_states = tf.convert_to_tensor(ns).reshape(BATCH_SIZE, 21)
        dones = tf.convert_to_tensor(d)

        return states, actions, action_indexs, rewards, next_states, dones

    def act(self, state):
        # if self.episode >= 0 and self.episode < 200:
        #     eps_threshold = -(self.episode/1000)+1+(self.episode)*(self.episode-200)/300000
        # else:
        #     eps_threshold = -(self.episode/1000)+1+(self.episode-200)*(self.episode-1000)

        eps_threshold = EPS_DECAY ** self.episode
        a_r = self.train_model(state)

        if rand.random() > eps_threshold:
            a_i = np.argmax(a_r)
            c = 1

        else:
            a_i = rand.randint(0, 41)
            c = 0

        a = return_action(a_i)

        return a, a_i, c, eps_threshold

    def run(self):
        if len(self.memory) < BATCH_SIZE:
            return 1

        states, actions, action_indexs, rewards, next_states, dones = self.convert_memory_to_input()
        loss = self.learn(states, actions, action_indexs, rewards, next_states, dones)
    
        return loss.numpy()
        
    @tf.function
    def learn(self, states, actions, action_indexs, rewards, next_states, dones):
        q_target = self.target_model(next_states)
        target_q = rewards + (1 - dones) * GAMMA * tf.reduce_max(q_target, axis=1, keepdims=True)

        with tf.GradientTape() as tape:
            current_q = self.train_model(states) # 현재 상황에서 할 수 있는 행동들의 q value
            current_q = tf.reduce_sum(current_q[action_indexs], axis=1, keepdims=True) # 실제 한 행동에 대한 q value

            loss = self.loss_fn(current_q, target_q)

        grads = tape.gradient(loss, self.train_model.trainable_weights)
        self.optim.apply_gradients(zip(grads, self.train_model.trainable_weights))

        return loss

# %%
agent = DQN_Agent()
rewards_hist = []
st_hist = []

goal_state = set_goal('basic_formula.xlsx').reshape(1, 21)
for e in range(1000):
    counter = [0 for i in range(42)]
    state = starting_state
    steps = 0
    rewards = 0
    c = 0

    if e % 5 == 0:
        agent.target_model.set_weights(agent.train_model.get_weights())

    while True:
        action, idx, t, eps = agent.act(state)
        counter[idx] += 1
        c += t
        next_state = return_state(state, action)
        reward = return_reward(next_state, goal_state)

        if steps == EPISODE_DONE or all(state[0][i] == goal_state[0][i] for i in range(21)):
            done = 1
        else:
            done = 0

        agent.memorize(state, action, idx, reward, next_state, done)
        loss = agent.run()
        
        state = next_state
        rewards += reward
        steps += 1

        # if steps % 10 == 0:
        #     print(f'steps: {steps}, reward: {reward}')

        if done:
            print(f'============={e}=============')
            print(f"rewards: {round(rewards, 3)}, net_loss: {round(loss, 3)}, number of most decision: {max(counter)}, desicion tendecy: {c}, eps: {round(eps, 5)}")
            print("=============================")
            rewards_hist.append(rewards)
            st_hist.append(state)
            break
# Out:
# =============0=============
# rewards: -174.799, net_loss: 1, number of most decision: 5, desicion tendecy: 0, eps: 0.99
# =============================
# =============1=============
# rewards: -171.181, net_loss: 1, number of most decision: 8, desicion tendecy: 5, eps: 0.9801
# =============================
# =============2=============
# rewards: -173.029, net_loss: 1, number of most decision: 6, desicion tendecy: 3, eps: 0.9703
# =============================
# =============3=============
# rewards: -172.265, net_loss: 1, number of most decision: 7, desicion tendecy: 1, eps: 0.9606
# =============================
# =============4=============
# rewards: -174.21, net_loss: 1, number of most decision: 9, desicion tendecy: 6, eps: 0.95099
# =============================
# =============5=============
# rewards: -173.163, net_loss: 1, number of most decision: 8, desicion tendecy: 6, eps: 0.94148
# =============================
# =============6=============
# rewards: -173.788, net_loss: 1, number of most decision: 11, desicion tendecy: 9, eps: 0.93207
# =============================
# =============7=============
# rewards: -172.291, net_loss: 1, number of most decision: 6, desicion tendecy: 4, eps: 0.92274
# =============================
# =============8=============
# rewards: -172.873, net_loss: 1, number of most decision: 10, desicion tendecy: 8, eps: 0.91352
# =============================
# =============9=============
# rewards: -173.327, net_loss: 3.336, number of most decision: 10, desicion tendecy: 8, eps: 0.90438
# =============================
# =============10=============
# rewards: -171.996, net_loss: 3.359, number of most decision: 12, desicion tendecy: 10, eps: 0.89534
# =============================
# =============11=============
# rewards: -171.944, net_loss: 3.34, number of most decision: 10, desicion tendecy: 10, eps: 0.88638
# =============================
# =============12=============
# rewards: -173.245, net_loss: 3.354, number of most decision: 14, desicion tendecy: 12, eps: 0.87752
# =============================
# =============13=============
# rewards: -172.154, net_loss: 3.364, number of most decision: 18, desicion tendecy: 18, eps: 0.86875
# =============================
# =============14=============
# rewards: -172.425, net_loss: 3.32, number of most decision: 16, desicion tendecy: 14, eps: 0.86006
# =============================
# =============15=============
# rewards: -172.138, net_loss: 3.323, number of most decision: 13, desicion tendecy: 12, eps: 0.85146
# =============================
# =============16=============
# rewards: -170.824, net_loss: 3.322, number of most decision: 23, desicion tendecy: 19, eps: 0.84294
# =============================
# =============17=============
# rewards: -171.965, net_loss: 3.311, number of most decision: 18, desicion tendecy: 16, eps: 0.83451
# =============================
# =============18=============
# rewards: -169.827, net_loss: 3.344, number of most decision: 20, desicion tendecy: 18, eps: 0.82617
# =============================
# =============19=============
# rewards: -171.87, net_loss: 3.309, number of most decision: 23, desicion tendecy: 21, eps: 0.81791
# =============================
# =============20=============
# rewards: -171.964, net_loss: 3.341, number of most decision: 17, desicion tendecy: 17, eps: 0.80973
# =============================
# =============21=============
# rewards: -172.1, net_loss: 3.291, number of most decision: 23, desicion tendecy: 22, eps: 0.80163
# =============================
# =============22=============
# rewards: -171.625, net_loss: 3.317, number of most decision: 24, desicion tendecy: 22, eps: 0.79361
# =============================
# =============23=============
# rewards: -169.884, net_loss: 3.328, number of most decision: 32, desicion tendecy: 30, eps: 0.78568
# =============================
# =============24=============
# rewards: -170.793, net_loss: 3.291, number of most decision: 28, desicion tendecy: 23, eps: 0.77782
# =============================
# =============25=============
# rewards: -170.431, net_loss: 3.302, number of most decision: 23, desicion tendecy: 23, eps: 0.77004
# =============================
# =============26=============
# rewards: -170.386, net_loss: 3.31, number of most decision: 19, desicion tendecy: 16, eps: 0.76234
# =============================
# =============27=============
# rewards: -169.402, net_loss: 3.271, number of most decision: 33, desicion tendecy: 31, eps: 0.75472
# =============================
# =============28=============
# rewards: -171.033, net_loss: 3.32, number of most decision: 36, desicion tendecy: 34, eps: 0.74717
# =============================
# =============29=============
# rewards: -169.665, net_loss: 3.32, number of most decision: 31, desicion tendecy: 31, eps: 0.7397
# =============================
# =============30=============
# rewards: -172.417, net_loss: 3.309, number of most decision: 22, desicion tendecy: 21, eps: 0.7323
# =============================
# =============31=============
# rewards: -169.653, net_loss: 3.298, number of most decision: 24, desicion tendecy: 23, eps: 0.72498
# =============================
# =============32=============
# rewards: -171.554, net_loss: 3.316, number of most decision: 32, desicion tendecy: 28, eps: 0.71773
# =============================
# =============33=============
# rewards: -168.195, net_loss: 3.308, number of most decision: 32, desicion tendecy: 32, eps: 0.71055
# =============================
# =============34=============
# rewards: -170.619, net_loss: 3.313, number of most decision: 27, desicion tendecy: 26, eps: 0.70345
# =============================
# =============35=============
# rewards: -167.529, net_loss: 3.304, number of most decision: 31, desicion tendecy: 28, eps: 0.69641
# =============================
# =============36=============
# rewards: -171.223, net_loss: 3.349, number of most decision: 36, desicion tendecy: 34, eps: 0.68945
# =============================
# =============37=============
# rewards: -170.45, net_loss: 3.316, number of most decision: 31, desicion tendecy: 29, eps: 0.68255
# =============================
# =============38=============
# rewards: -169.839, net_loss: 3.329, number of most decision: 46, desicion tendecy: 44, eps: 0.67573
# =============================
# =============39=============
# rewards: -169.58, net_loss: 3.296, number of most decision: 37, desicion tendecy: 36, eps: 0.66897
# =============================
# =============40=============
# rewards: -168.716, net_loss: 3.273, number of most decision: 33, desicion tendecy: 31, eps: 0.66228
# =============================
# =============41=============
# rewards: -169.195, net_loss: 3.294, number of most decision: 44, desicion tendecy: 42, eps: 0.65566
# =============================
# =============42=============
# rewards: -172.014, net_loss: 3.316, number of most decision: 29, desicion tendecy: 28, eps: 0.6491
# =============================
# =============43=============
# rewards: -169.663, net_loss: 3.301, number of most decision: 37, desicion tendecy: 35, eps: 0.64261
# =============================
# =============44=============
# rewards: -171.038, net_loss: 3.3, number of most decision: 36, desicion tendecy: 33, eps: 0.63619
# =============================
# =============45=============
# rewards: -170.916, net_loss: 3.311, number of most decision: 44, desicion tendecy: 43, eps: 0.62982
# =============================
# =============46=============
# rewards: -169.38, net_loss: 3.287, number of most decision: 48, desicion tendecy: 48, eps: 0.62353
# =============================
# =============47=============
# rewards: -169.877, net_loss: 3.303, number of most decision: 34, desicion tendecy: 34, eps: 0.61729
# =============================
# =============48=============
# rewards: -172.053, net_loss: 3.304, number of most decision: 41, desicion tendecy: 40, eps: 0.61112
# =============================
# =============49=============
# rewards: -168.607, net_loss: 3.276, number of most decision: 42, desicion tendecy: 42, eps: 0.60501
# =============================
# =============50=============
# rewards: -169.766, net_loss: 3.302, number of most decision: 40, desicion tendecy: 39, eps: 0.59896
# =============================
# =============51=============
# rewards: -169.613, net_loss: 3.289, number of most decision: 41, desicion tendecy: 40, eps: 0.59297
# =============================
# =============52=============
# rewards: -169.026, net_loss: 3.287, number of most decision: 43, desicion tendecy: 40, eps: 0.58704
# =============================
# =============53=============
# rewards: -169.519, net_loss: 3.298, number of most decision: 41, desicion tendecy: 39, eps: 0.58117
# =============================
# =============54=============
# rewards: -170.264, net_loss: 3.31, number of most decision: 54, desicion tendecy: 53, eps: 0.57535
# =============================
# =============55=============
# rewards: -168.552, net_loss: 3.274, number of most decision: 51, desicion tendecy: 49, eps: 0.5696
# =============================
# =============56=============
# rewards: -168.745, net_loss: 3.253, number of most decision: 51, desicion tendecy: 51, eps: 0.56391
# =============================
# =============57=============
# rewards: -169.141, net_loss: 3.283, number of most decision: 49, desicion tendecy: 48, eps: 0.55827
# =============================
# =============58=============
# rewards: -167.98, net_loss: 3.298, number of most decision: 43, desicion tendecy: 42, eps: 0.55268
# =============================
# =============59=============
# rewards: -170.065, net_loss: 3.273, number of most decision: 47, desicion tendecy: 45, eps: 0.54716
# =============================
# =============60=============
# rewards: -170.321, net_loss: 3.303, number of most decision: 43, desicion tendecy: 42, eps: 0.54169
# =============================
# =============61=============
# rewards: -169.091, net_loss: 3.301, number of most decision: 47, desicion tendecy: 46, eps: 0.53627
# =============================
# =============62=============
# rewards: -169.575, net_loss: 3.275, number of most decision: 52, desicion tendecy: 52, eps: 0.53091
# =============================
# =============63=============
# rewards: -169.968, net_loss: 3.28, number of most decision: 52, desicion tendecy: 51, eps: 0.5256
# =============================
# =============64=============
# rewards: -168.906, net_loss: 3.243, number of most decision: 50, desicion tendecy: 50, eps: 0.52034
# =============================
# =============65=============
# rewards: -169.131, net_loss: 3.381, number of most decision: 47, desicion tendecy: 47, eps: 0.51514
# =============================
# =============66=============
# rewards: -170.887, net_loss: 3.259, number of most decision: 45, desicion tendecy: 42, eps: 0.50999
# =============================
# =============67=============
# rewards: -170.608, net_loss: 3.297, number of most decision: 54, desicion tendecy: 53, eps: 0.50489
# =============================
# =============68=============
# rewards: -169.803, net_loss: 3.267, number of most decision: 42, desicion tendecy: 40, eps: 0.49984
# =============================
# =============69=============
# rewards: -168.905, net_loss: 3.286, number of most decision: 54, desicion tendecy: 53, eps: 0.49484
# =============================
# =============70=============
# rewards: -170.128, net_loss: 3.272, number of most decision: 55, desicion tendecy: 52, eps: 0.48989
# =============================
# =============71=============
# rewards: -167.948, net_loss: 3.224, number of most decision: 51, desicion tendecy: 47, eps: 0.48499
# =============================
# =============72=============
# rewards: -169.001, net_loss: 3.286, number of most decision: 50, desicion tendecy: 48, eps: 0.48014
# =============================
# =============73=============
# rewards: -169.846, net_loss: 3.284, number of most decision: 51, desicion tendecy: 51, eps: 0.47534
# =============================
# =============74=============
# rewards: -169.485, net_loss: 3.261, number of most decision: 51, desicion tendecy: 49, eps: 0.47059
# =============================
# =============75=============
# rewards: -167.629, net_loss: 3.253, number of most decision: 62, desicion tendecy: 62, eps: 0.46588
# =============================
# =============76=============
# rewards: -168.452, net_loss: 3.255, number of most decision: 59, desicion tendecy: 57, eps: 0.46122
# =============================
# =============77=============
# rewards: -169.307, net_loss: 3.259, number of most decision: 59, desicion tendecy: 57, eps: 0.45661
# =============================
# =============78=============
# rewards: -169.424, net_loss: 3.284, number of most decision: 59, desicion tendecy: 58, eps: 0.45204
# =============================
# =============79=============
# rewards: -169.866, net_loss: 3.25, number of most decision: 53, desicion tendecy: 50, eps: 0.44752
# =============================
# =============80=============
# rewards: -168.278, net_loss: 3.264, number of most decision: 62, desicion tendecy: 59, eps: 0.44305
# =============================
# =============81=============
# rewards: -170.332, net_loss: 3.282, number of most decision: 57, desicion tendecy: 55, eps: 0.43862
# =============================
# =============82=============
# rewards: -167.95, net_loss: 3.235, number of most decision: 61, desicion tendecy: 59, eps: 0.43423
# =============================
# =============83=============
# rewards: -168.224, net_loss: 3.284, number of most decision: 63, desicion tendecy: 62, eps: 0.42989
# =============================
# =============84=============
# rewards: -169.66, net_loss: 3.42, number of most decision: 56, desicion tendecy: 56, eps: 0.42559
# =============================
# =============85=============
# rewards: -168.867, net_loss: 3.302, number of most decision: 58, desicion tendecy: 58, eps: 0.42133
# =============================
# =============86=============
# rewards: -170.334, net_loss: 3.25, number of most decision: 54, desicion tendecy: 53, eps: 0.41712
# =============================
# =============87=============
# rewards: -169.115, net_loss: 3.243, number of most decision: 56, desicion tendecy: 56, eps: 0.41295
# =============================
# =============88=============
# rewards: -167.969, net_loss: 3.282, number of most decision: 57, desicion tendecy: 56, eps: 0.40882
# =============================
# =============89=============
# rewards: -170.117, net_loss: 3.264, number of most decision: 60, desicion tendecy: 58, eps: 0.40473
# =============================
# =============90=============
# rewards: -168.826, net_loss: 3.259, number of most decision: 55, desicion tendecy: 55, eps: 0.40068
# =============================
# =============91=============
# rewards: -168.042, net_loss: 3.267, number of most decision: 61, desicion tendecy: 60, eps: 0.39668
# =============================
# =============92=============
# rewards: -168.618, net_loss: 3.284, number of most decision: 57, desicion tendecy: 55, eps: 0.39271
# =============================
# =============93=============
# rewards: -167.833, net_loss: 3.409, number of most decision: 67, desicion tendecy: 67, eps: 0.38878
# =============================
# =============94=============
# rewards: -169.595, net_loss: 3.402, number of most decision: 64, desicion tendecy: 63, eps: 0.3849
# =============================
# =============95=============
# rewards: -169.808, net_loss: 3.255, number of most decision: 66, desicion tendecy: 64, eps: 0.38105
# =============================
# =============96=============
# rewards: -169.5, net_loss: 3.248, number of most decision: 64, desicion tendecy: 64, eps: 0.37724
# =============================
# =============97=============
# rewards: -167.774, net_loss: 3.269, number of most decision: 72, desicion tendecy: 71, eps: 0.37346
# =============================
# =============98=============
# rewards: -169.586, net_loss: 3.235, number of most decision: 70, desicion tendecy: 69, eps: 0.36973
# =============================
# =============99=============
# rewards: -169.178, net_loss: 3.226, number of most decision: 62, desicion tendecy: 62, eps: 0.36603
# =============================
# =============100=============
# rewards: -169.879, net_loss: 3.253, number of most decision: 76, desicion tendecy: 74, eps: 0.36237
# =============================
# =============101=============
# rewards: -170.465, net_loss: 3.273, number of most decision: 69, desicion tendecy: 68, eps: 0.35875
# =============================
# =============102=============
# rewards: -169.615, net_loss: 3.244, number of most decision: 72, desicion tendecy: 71, eps: 0.35516
# =============================
# =============103=============
# rewards: -168.739, net_loss: 3.267, number of most decision: 70, desicion tendecy: 70, eps: 0.35161
# =============================
# =============104=============
# rewards: -169.62, net_loss: 3.254, number of most decision: 57, desicion tendecy: 55, eps: 0.34809
# =============================
# =============105=============
# rewards: -169.611, net_loss: 3.259, number of most decision: 67, desicion tendecy: 67, eps: 0.34461
# =============================
# =============106=============
# rewards: -169.208, net_loss: 3.301, number of most decision: 64, desicion tendecy: 62, eps: 0.34117
# =============================
# =============107=============
# rewards: -168.446, net_loss: 3.218, number of most decision: 63, desicion tendecy: 62, eps: 0.33775
# =============================
# =============108=============
# rewards: -168.678, net_loss: 3.254, number of most decision: 63, desicion tendecy: 62, eps: 0.33438
# =============================
# =============109=============
# rewards: -168.469, net_loss: 3.259, number of most decision: 66, desicion tendecy: 65, eps: 0.33103
# =============================
# =============110=============
# rewards: -168.239, net_loss: 3.277, number of most decision: 66, desicion tendecy: 65, eps: 0.32772
# =============================
# =============111=============
# rewards: -169.21, net_loss: 3.231, number of most decision: 81, desicion tendecy: 81, eps: 0.32445
# =============================
# =============112=============
# rewards: -168.89, net_loss: 3.287, number of most decision: 70, desicion tendecy: 70, eps: 0.3212
# =============================
# =============113=============
# rewards: -168.564, net_loss: 3.286, number of most decision: 70, desicion tendecy: 70, eps: 0.31799
# =============================
# =============114=============
# rewards: -169.68, net_loss: 3.286, number of most decision: 62, desicion tendecy: 62, eps: 0.31481
# =============================
# =============115=============
# rewards: -169.474, net_loss: 3.26, number of most decision: 71, desicion tendecy: 71, eps: 0.31166
# =============================
# =============116=============
# rewards: -170.083, net_loss: 3.236, number of most decision: 68, desicion tendecy: 68, eps: 0.30854
# =============================
# =============117=============
# rewards: -168.444, net_loss: 3.235, number of most decision: 70, desicion tendecy: 67, eps: 0.30546
# =============================
# =============118=============
# rewards: -169.707, net_loss: 3.287, number of most decision: 70, desicion tendecy: 69, eps: 0.3024
# =============================
# =============119=============
# rewards: -169.364, net_loss: 3.28, number of most decision: 72, desicion tendecy: 72, eps: 0.29938
# =============================
# =============120=============
# rewards: -169.267, net_loss: 3.29, number of most decision: 74, desicion tendecy: 72, eps: 0.29639
# =============================
# =============121=============
# rewards: -168.13, net_loss: 3.233, number of most decision: 73, desicion tendecy: 73, eps: 0.29342
# =============================
# =============122=============
# rewards: -167.827, net_loss: 3.256, number of most decision: 79, desicion tendecy: 78, eps: 0.29049
# =============================
# =============123=============
# rewards: -168.69, net_loss: 3.271, number of most decision: 68, desicion tendecy: 68, eps: 0.28758
# =============================
# =============124=============
# rewards: -168.62, net_loss: 3.262, number of most decision: 74, desicion tendecy: 73, eps: 0.28471
# =============================
# =============125=============
# rewards: -168.921, net_loss: 3.224, number of most decision: 67, desicion tendecy: 67, eps: 0.28186
# =============================
# =============126=============
# rewards: -168.734, net_loss: 3.265, number of most decision: 71, desicion tendecy: 69, eps: 0.27904
# =============================
# =============127=============
# rewards: -169.894, net_loss: 3.203, number of most decision: 77, desicion tendecy: 77, eps: 0.27625
# =============================
# =============128=============
# rewards: -169.04, net_loss: 3.218, number of most decision: 71, desicion tendecy: 70, eps: 0.27349
# =============================
# =============129=============
# rewards: -170.66, net_loss: 3.269, number of most decision: 70, desicion tendecy: 69, eps: 0.27075
# =============================
# =============130=============
# rewards: -169.364, net_loss: 3.266, number of most decision: 75, desicion tendecy: 74, eps: 0.26805
# =============================
# =============131=============
# rewards: -169.182, net_loss: 3.276, number of most decision: 77, desicion tendecy: 77, eps: 0.26537
# =============================
# =============132=============
# rewards: -168.258, net_loss: 3.245, number of most decision: 76, desicion tendecy: 75, eps: 0.26271
# =============================
# =============133=============
# rewards: -169.716, net_loss: 3.196, number of most decision: 76, desicion tendecy: 75, eps: 0.26009
# =============================
# =============134=============
# rewards: -168.453, net_loss: 3.246, number of most decision: 82, desicion tendecy: 82, eps: 0.25748
# =============================
# =============135=============
# rewards: -168.124, net_loss: 3.253, number of most decision: 81, desicion tendecy: 79, eps: 0.25491
# =============================
# =============136=============
# rewards: -168.729, net_loss: 3.228, number of most decision: 68, desicion tendecy: 68, eps: 0.25236
# =============================
# =============137=============
# rewards: -169.137, net_loss: 3.22, number of most decision: 76, desicion tendecy: 75, eps: 0.24984
# =============================
# =============138=============
# rewards: -169.302, net_loss: 3.271, number of most decision: 80, desicion tendecy: 78, eps: 0.24734
# =============================
# =============139=============
# rewards: -168.487, net_loss: 3.256, number of most decision: 70, desicion tendecy: 70, eps: 0.24487
# =============================
# =============140=============
# rewards: -171.04, net_loss: 3.259, number of most decision: 77, desicion tendecy: 77, eps: 0.24242
# =============================
# =============141=============
# rewards: -169.548, net_loss: 3.2, number of most decision: 80, desicion tendecy: 80, eps: 0.23999
# =============================
# =============142=============
# rewards: -169.58, net_loss: 3.248, number of most decision: 78, desicion tendecy: 78, eps: 0.23759
# =============================
# =============143=============
# rewards: -168.254, net_loss: 3.321, number of most decision: 78, desicion tendecy: 78, eps: 0.23522
# =============================
# =============144=============
# rewards: -168.875, net_loss: 3.255, number of most decision: 70, desicion tendecy: 69, eps: 0.23286
# =============================
# =============145=============
# rewards: -167.95, net_loss: 3.298, number of most decision: 75, desicion tendecy: 75, eps: 0.23054
# =============================
# =============146=============
# rewards: -170.304, net_loss: 3.27, number of most decision: 75, desicion tendecy: 75, eps: 0.22823
# =============================
# =============147=============
# rewards: -169.286, net_loss: 3.261, number of most decision: 80, desicion tendecy: 80, eps: 0.22595
# =============================
# =============148=============
# rewards: -168.902, net_loss: 3.26, number of most decision: 80, desicion tendecy: 80, eps: 0.22369
# =============================
# =============149=============
# rewards: -169.619, net_loss: 3.242, number of most decision: 76, desicion tendecy: 76, eps: 0.22145
# =============================
# =============150=============
# rewards: -168.188, net_loss: 3.265, number of most decision: 78, desicion tendecy: 78, eps: 0.21924
# =============================
# =============151=============
# rewards: -168.703, net_loss: 3.295, number of most decision: 81, desicion tendecy: 80, eps: 0.21704
# =============================
# =============152=============
# rewards: -169.07, net_loss: 3.239, number of most decision: 82, desicion tendecy: 82, eps: 0.21487
# =============================
# =============153=============
# rewards: -168.268, net_loss: 3.229, number of most decision: 80, desicion tendecy: 80, eps: 0.21273
# =============================
# =============154=============
# rewards: -168.077, net_loss: 3.201, number of most decision: 73, desicion tendecy: 72, eps: 0.2106
# =============================
# =============155=============
# rewards: -169.802, net_loss: 3.254, number of most decision: 86, desicion tendecy: 85, eps: 0.20849
# =============================
# =============156=============
# rewards: -169.577, net_loss: 3.2, number of most decision: 72, desicion tendecy: 72, eps: 0.20641
# =============================
# =============157=============
# rewards: -167.828, net_loss: 3.2, number of most decision: 76, desicion tendecy: 75, eps: 0.20434
# =============================
# =============158=============
# rewards: -168.262, net_loss: 3.393, number of most decision: 79, desicion tendecy: 79, eps: 0.2023
# =============================
# =============159=============
# rewards: -169.329, net_loss: 3.208, number of most decision: 82, desicion tendecy: 82, eps: 0.20028
# =============================
# =============160=============
# rewards: -169.151, net_loss: 3.229, number of most decision: 83, desicion tendecy: 83, eps: 0.19827
# =============================
# =============161=============
# rewards: -169.49, net_loss: 3.23, number of most decision: 85, desicion tendecy: 84, eps: 0.19629
# =============================
# =============162=============
# rewards: -168.415, net_loss: 3.169, number of most decision: 82, desicion tendecy: 81, eps: 0.19433
# =============================
# =============163=============
# rewards: -169.438, net_loss: 3.238, number of most decision: 80, desicion tendecy: 80, eps: 0.19239
# =============================
# =============164=============
# rewards: -168.779, net_loss: 3.249, number of most decision: 85, desicion tendecy: 85, eps: 0.19046
# =============================
# =============165=============
# rewards: -169.377, net_loss: 3.261, number of most decision: 81, desicion tendecy: 81, eps: 0.18856
# =============================
# =============166=============
# rewards: -168.096, net_loss: 3.187, number of most decision: 78, desicion tendecy: 78, eps: 0.18667
# =============================
# =============167=============
# rewards: -169.864, net_loss: 3.189, number of most decision: 84, desicion tendecy: 84, eps: 0.1848
# =============================
# =============168=============
# rewards: -168.942, net_loss: 3.302, number of most decision: 86, desicion tendecy: 86, eps: 0.18296
# =============================
# =============169=============
# rewards: -168.557, net_loss: 3.253, number of most decision: 83, desicion tendecy: 83, eps: 0.18113
# =============================
# =============170=============
# rewards: -169.186, net_loss: 3.236, number of most decision: 87, desicion tendecy: 87, eps: 0.17932
# =============================
# =============171=============
# rewards: -168.625, net_loss: 3.248, number of most decision: 83, desicion tendecy: 81, eps: 0.17752
# =============================
# =============172=============
# rewards: -168.754, net_loss: 3.257, number of most decision: 83, desicion tendecy: 83, eps: 0.17575
# =============================
# =============173=============
# rewards: -168.88, net_loss: 3.257, number of most decision: 82, desicion tendecy: 82, eps: 0.17399
# =============================
# =============174=============
# rewards: -169.255, net_loss: 3.292, number of most decision: 86, desicion tendecy: 86, eps: 0.17225
# =============================
# =============175=============
# rewards: -168.765, net_loss: 3.214, number of most decision: 83, desicion tendecy: 83, eps: 0.17053
# =============================
# =============176=============
# rewards: -169.101, net_loss: 3.261, number of most decision: 87, desicion tendecy: 86, eps: 0.16882
# =============================
# =============177=============
# rewards: -169.238, net_loss: 3.269, number of most decision: 92, desicion tendecy: 92, eps: 0.16713
# =============================
# =============178=============
# rewards: -168.853, net_loss: 3.253, number of most decision: 85, desicion tendecy: 83, eps: 0.16546
# =============================
# =============179=============
# rewards: -169.754, net_loss: 3.257, number of most decision: 77, desicion tendecy: 77, eps: 0.16381
# =============================
# =============180=============
# rewards: -169.135, net_loss: 3.252, number of most decision: 92, desicion tendecy: 90, eps: 0.16217
# =============================
# =============181=============
# rewards: -168.188, net_loss: 3.271, number of most decision: 82, desicion tendecy: 82, eps: 0.16055
# =============================
# =============182=============
# rewards: -169.469, net_loss: 3.254, number of most decision: 84, desicion tendecy: 83, eps: 0.15894
# =============================
# =============183=============
# rewards: -169.413, net_loss: 3.244, number of most decision: 85, desicion tendecy: 84, eps: 0.15735
# =============================
# =============184=============
# rewards: -169.151, net_loss: 3.217, number of most decision: 89, desicion tendecy: 89, eps: 0.15578
# =============================
# =============185=============
# rewards: -169.803, net_loss: 3.162, number of most decision: 77, desicion tendecy: 77, eps: 0.15422
# =============================
# =============186=============
# rewards: -169.69, net_loss: 3.303, number of most decision: 84, desicion tendecy: 84, eps: 0.15268
# =============================
# =============187=============
# rewards: -169.484, net_loss: 3.275, number of most decision: 88, desicion tendecy: 88, eps: 0.15115
# =============================
# =============188=============
# rewards: -169.091, net_loss: 3.275, number of most decision: 87, desicion tendecy: 86, eps: 0.14964
# =============================
# =============189=============
# rewards: -169.681, net_loss: 3.284, number of most decision: 90, desicion tendecy: 90, eps: 0.14814
# =============================
# =============190=============
# rewards: -169.809, net_loss: 3.196, number of most decision: 89, desicion tendecy: 87, eps: 0.14666
# =============================
# =============191=============
# rewards: -169.129, net_loss: 3.276, number of most decision: 85, desicion tendecy: 84, eps: 0.1452
# =============================
# =============192=============
# rewards: -169.491, net_loss: 3.22, number of most decision: 88, desicion tendecy: 88, eps: 0.14374
# =============================
# =============193=============
# rewards: -169.004, net_loss: 3.281, number of most decision: 91, desicion tendecy: 89, eps: 0.14231
# =============================
# =============194=============
# rewards: -168.902, net_loss: 3.254, number of most decision: 90, desicion tendecy: 87, eps: 0.14088
# =============================
# =============195=============
# rewards: -169.466, net_loss: 3.234, number of most decision: 84, desicion tendecy: 84, eps: 0.13948
# =============================
# =============196=============
# rewards: -169.406, net_loss: 3.139, number of most decision: 94, desicion tendecy: 94, eps: 0.13808
# =============================
# =============197=============
# rewards: -169.04, net_loss: 3.189, number of most decision: 85, desicion tendecy: 84, eps: 0.1367
# =============================
# =============198=============
# rewards: -168.423, net_loss: 3.278, number of most decision: 85, desicion tendecy: 85, eps: 0.13533
# =============================
# =============199=============
# rewards: -169.703, net_loss: 3.268, number of most decision: 88, desicion tendecy: 88, eps: 0.13398
# =============================
# =============200=============
# rewards: -169.24, net_loss: 3.278, number of most decision: 93, desicion tendecy: 93, eps: 0.13264
# =============================
# =============201=============
# rewards: -168.653, net_loss: 3.178, number of most decision: 84, desicion tendecy: 84, eps: 0.13131
# =============================
# =============202=============
# rewards: -169.216, net_loss: 3.254, number of most decision: 87, desicion tendecy: 87, eps: 0.13
# =============================
# =============203=============
# rewards: -169.088, net_loss: 3.259, number of most decision: 87, desicion tendecy: 87, eps: 0.1287
# =============================
# =============204=============
# rewards: -168.989, net_loss: 3.212, number of most decision: 88, desicion tendecy: 88, eps: 0.12741
# =============================
# =============205=============
# rewards: -169.235, net_loss: 3.258, number of most decision: 95, desicion tendecy: 94, eps: 0.12614
# =============================
# =============206=============
# rewards: -169.428, net_loss: 3.184, number of most decision: 89, desicion tendecy: 88, eps: 0.12488
# =============================
# =============207=============
# rewards: -169.149, net_loss: 3.244, number of most decision: 91, desicion tendecy: 91, eps: 0.12363
# =============================
# =============208=============
# rewards: -169.075, net_loss: 3.243, number of most decision: 84, desicion tendecy: 84, eps: 0.12239
# =============================
# =============209=============
# rewards: -169.504, net_loss: 3.247, number of most decision: 89, desicion tendecy: 89, eps: 0.12117
# =============================
# =============210=============
# rewards: -169.372, net_loss: 3.238, number of most decision: 90, desicion tendecy: 89, eps: 0.11996
# =============================
# =============211=============
# rewards: -169.342, net_loss: 3.219, number of most decision: 92, desicion tendecy: 92, eps: 0.11876
# =============================
# =============212=============
# rewards: -169.483, net_loss: 3.25, number of most decision: 89, desicion tendecy: 88, eps: 0.11757
# =============================
# =============213=============
# rewards: -169.475, net_loss: 3.254, number of most decision: 86, desicion tendecy: 86, eps: 0.11639
# =============================
# =============214=============
# rewards: -169.598, net_loss: 3.265, number of most decision: 87, desicion tendecy: 87, eps: 0.11523
# =============================
# =============215=============
# rewards: -170.263, net_loss: 3.247, number of most decision: 88, desicion tendecy: 88, eps: 0.11408
# =============================
# =============216=============
# rewards: -169.832, net_loss: 3.246, number of most decision: 93, desicion tendecy: 92, eps: 0.11294
# =============================
# =============217=============
# rewards: -168.297, net_loss: 3.212, number of most decision: 84, desicion tendecy: 84, eps: 0.11181
# =============================
# =============218=============
# rewards: -169.562, net_loss: 3.255, number of most decision: 94, desicion tendecy: 94, eps: 0.11069
# =============================
# =============219=============
# rewards: -169.317, net_loss: 3.208, number of most decision: 90, desicion tendecy: 89, eps: 0.10958
# =============================
# =============220=============
# rewards: -169.629, net_loss: 3.365, number of most decision: 93, desicion tendecy: 92, eps: 0.10849
# =============================
# =============221=============
# rewards: -169.142, net_loss: 3.26, number of most decision: 92, desicion tendecy: 91, eps: 0.1074
# =============================
# =============222=============
# rewards: -169.908, net_loss: 3.258, number of most decision: 90, desicion tendecy: 90, eps: 0.10633
# =============================
# =============223=============
# rewards: -169.572, net_loss: 3.226, number of most decision: 90, desicion tendecy: 89, eps: 0.10526
# =============================
# =============224=============
# rewards: -170.006, net_loss: 3.224, number of most decision: 93, desicion tendecy: 93, eps: 0.10421
# =============================
# =============225=============
# rewards: -169.614, net_loss: 3.223, number of most decision: 84, desicion tendecy: 84, eps: 0.10317
# =============================
# =============226=============
# rewards: -169.533, net_loss: 3.248, number of most decision: 93, desicion tendecy: 92, eps: 0.10214
# =============================
# =============227=============
# rewards: -169.579, net_loss: 3.255, number of most decision: 90, desicion tendecy: 89, eps: 0.10112
# =============================
# =============228=============
# rewards: -169.274, net_loss: 3.23, number of most decision: 86, desicion tendecy: 85, eps: 0.10011
# =============================
# =============229=============
# rewards: -169.638, net_loss: 3.204, number of most decision: 89, desicion tendecy: 88, eps: 0.0991
# =============================
# =============230=============
# rewards: -168.614, net_loss: 3.252, number of most decision: 87, desicion tendecy: 87, eps: 0.09811
# =============================
# =============231=============
# rewards: -169.728, net_loss: 3.222, number of most decision: 95, desicion tendecy: 95, eps: 0.09713
# =============================
# =============232=============
# rewards: -169.377, net_loss: 3.169, number of most decision: 94, desicion tendecy: 94, eps: 0.09616
# =============================
# =============233=============
# rewards: -169.738, net_loss: 3.185, number of most decision: 92, desicion tendecy: 92, eps: 0.0952
# =============================
# =============234=============
# rewards: -169.836, net_loss: 3.241, number of most decision: 92, desicion tendecy: 92, eps: 0.09425
# =============================
# =============235=============
# rewards: -169.238, net_loss: 3.204, number of most decision: 95, desicion tendecy: 95, eps: 0.09331
# =============================
# =============236=============
# rewards: -170.013, net_loss: 3.246, number of most decision: 96, desicion tendecy: 96, eps: 0.09237
# =============================
# =============237=============
# rewards: -169.715, net_loss: 3.244, number of most decision: 93, desicion tendecy: 93, eps: 0.09145
# =============================
# =============238=============
# rewards: -169.469, net_loss: 3.238, number of most decision: 89, desicion tendecy: 89, eps: 0.09053
# =============================
# =============239=============
# rewards: -169.528, net_loss: 3.001, number of most decision: 91, desicion tendecy: 90, eps: 0.08963
# =============================
# =============240=============
# rewards: -169.606, net_loss: 3.325, number of most decision: 90, desicion tendecy: 90, eps: 0.08873
# =============================
# =============241=============
# rewards: -168.424, net_loss: 3.217, number of most decision: 90, desicion tendecy: 90, eps: 0.08785
# =============================
# =============242=============
# rewards: -169.448, net_loss: 2.971, number of most decision: 92, desicion tendecy: 92, eps: 0.08697
# =============================
# =============243=============
# rewards: -169.09, net_loss: 3.219, number of most decision: 95, desicion tendecy: 94, eps: 0.0861
# =============================
# =============244=============
# rewards: -169.739, net_loss: 3.317, number of most decision: 95, desicion tendecy: 94, eps: 0.08524
# =============================
# =============245=============
# rewards: -170.379, net_loss: 3.287, number of most decision: 94, desicion tendecy: 94, eps: 0.08438
# =============================
# =============246=============
# rewards: -169.51, net_loss: 3.293, number of most decision: 99, desicion tendecy: 99, eps: 0.08354
# =============================
# =============247=============
# rewards: -170.058, net_loss: 3.198, number of most decision: 94, desicion tendecy: 94, eps: 0.0827
# =============================
# =============248=============
# rewards: -169.335, net_loss: 3.002, number of most decision: 96, desicion tendecy: 96, eps: 0.08188
# =============================
# =============249=============
# rewards: -169.95, net_loss: 3.225, number of most decision: 98, desicion tendecy: 97, eps: 0.08106
# =============================
# =============250=============
# rewards: -169.393, net_loss: 3.247, number of most decision: 92, desicion tendecy: 92, eps: 0.08025
# =============================
# =============251=============
# rewards: -169.5, net_loss: 3.229, number of most decision: 93, desicion tendecy: 92, eps: 0.07945
# =============================
# =============252=============
# rewards: -169.422, net_loss: 3.248, number of most decision: 91, desicion tendecy: 91, eps: 0.07865
# =============================
# =============253=============
# rewards: -169.179, net_loss: 3.012, number of most decision: 94, desicion tendecy: 94, eps: 0.07786
# =============================
# =============254=============
# rewards: -169.102, net_loss: 3.269, number of most decision: 91, desicion tendecy: 91, eps: 0.07709
# =============================
# =============255=============
# rewards: -169.504, net_loss: 3.083, number of most decision: 92, desicion tendecy: 92, eps: 0.07631
# =============================
# =============256=============
# rewards: -169.524, net_loss: 3.226, number of most decision: 94, desicion tendecy: 94, eps: 0.07555
# =============================
# =============257=============
# rewards: -170.032, net_loss: 3.241, number of most decision: 93, desicion tendecy: 93, eps: 0.0748
# =============================
# =============258=============
# rewards: -169.382, net_loss: 3.243, number of most decision: 93, desicion tendecy: 93, eps: 0.07405
# =============================
# =============259=============
# rewards: -169.205, net_loss: 3.23, number of most decision: 94, desicion tendecy: 94, eps: 0.07331
# =============================
# =============260=============
# rewards: -169.169, net_loss: 3.203, number of most decision: 95, desicion tendecy: 95, eps: 0.07257
# =============================
# =============261=============
# rewards: -169.494, net_loss: 3.261, number of most decision: 96, desicion tendecy: 96, eps: 0.07185
# =============================
# =============262=============
# rewards: -169.402, net_loss: 3.094, number of most decision: 95, desicion tendecy: 94, eps: 0.07113
# =============================
# =============263=============
# rewards: -169.577, net_loss: 3.187, number of most decision: 94, desicion tendecy: 94, eps: 0.07042
# =============================
# =============264=============
# rewards: -169.209, net_loss: 3.233, number of most decision: 90, desicion tendecy: 90, eps: 0.06972
# =============================
# =============265=============
# rewards: -169.988, net_loss: 3.231, number of most decision: 97, desicion tendecy: 97, eps: 0.06902
# =============================
# =============266=============
# rewards: -169.237, net_loss: 3.252, number of most decision: 92, desicion tendecy: 92, eps: 0.06833
# =============================
# =============267=============
# rewards: -169.302, net_loss: 3.252, number of most decision: 95, desicion tendecy: 95, eps: 0.06764
# =============================
# =============268=============
# rewards: -169.334, net_loss: 3.241, number of most decision: 94, desicion tendecy: 93, eps: 0.06697
# =============================
# =============269=============
# rewards: -168.856, net_loss: 3.235, number of most decision: 96, desicion tendecy: 96, eps: 0.0663
# =============================
# =============270=============
# rewards: -169.261, net_loss: 3.137, number of most decision: 97, desicion tendecy: 97, eps: 0.06564
# =============================
# =============271=============
# rewards: -169.4, net_loss: 3.179, number of most decision: 94, desicion tendecy: 94, eps: 0.06498
# =============================
# =============272=============
# rewards: -169.691, net_loss: 3.3, number of most decision: 97, desicion tendecy: 97, eps: 0.06433
# =============================
# =============273=============
# rewards: -169.87, net_loss: 2.937, number of most decision: 96, desicion tendecy: 96, eps: 0.06369
# =============================
# =============274=============
# rewards: -169.321, net_loss: 3.219, number of most decision: 96, desicion tendecy: 94, eps: 0.06305
# =============================
# =============275=============
# rewards: -169.239, net_loss: 3.215, number of most decision: 92, desicion tendecy: 92, eps: 0.06242
# =============================
# =============276=============
# rewards: -169.881, net_loss: 3.246, number of most decision: 92, desicion tendecy: 92, eps: 0.06179
# =============================
# =============277=============
# rewards: -169.22, net_loss: 3.189, number of most decision: 87, desicion tendecy: 87, eps: 0.06118
# =============================
# =============278=============
# rewards: -169.552, net_loss: 3.252, number of most decision: 98, desicion tendecy: 98, eps: 0.06056
# =============================
# =============279=============
# rewards: -169.188, net_loss: 3.238, number of most decision: 97, desicion tendecy: 97, eps: 0.05996
# =============================
# =============280=============
# rewards: -169.722, net_loss: 3.264, number of most decision: 98, desicion tendecy: 98, eps: 0.05936
# =============================
# =============281=============
# rewards: -170.61, net_loss: 3.249, number of most decision: 90, desicion tendecy: 90, eps: 0.05877
# =============================
# =============282=============
# rewards: -168.895, net_loss: 3.286, number of most decision: 95, desicion tendecy: 94, eps: 0.05818
# =============================
# =============283=============
# rewards: -169.26, net_loss: 3.025, number of most decision: 93, desicion tendecy: 93, eps: 0.0576
# =============================
# =============284=============
# rewards: -169.73, net_loss: 3.196, number of most decision: 97, desicion tendecy: 97, eps: 0.05702
# =============================
# =============285=============
# rewards: -168.922, net_loss: 3.298, number of most decision: 95, desicion tendecy: 95, eps: 0.05645
# =============================
# =============286=============
# rewards: -169.359, net_loss: 3.23, number of most decision: 94, desicion tendecy: 93, eps: 0.05589
# =============================
# =============287=============
# rewards: -169.873, net_loss: 3.227, number of most decision: 97, desicion tendecy: 97, eps: 0.05533
# =============================
# =============288=============
# rewards: -169.532, net_loss: 3.156, number of most decision: 97, desicion tendecy: 97, eps: 0.05477
# =============================
# =============289=============
# rewards: -169.865, net_loss: 3.184, number of most decision: 94, desicion tendecy: 93, eps: 0.05423
# =============================
# =============290=============
# rewards: -169.191, net_loss: 3.232, number of most decision: 97, desicion tendecy: 97, eps: 0.05368
# =============================
# =============291=============
# rewards: -168.775, net_loss: 3.19, number of most decision: 91, desicion tendecy: 91, eps: 0.05315
# =============================
# =============292=============
# rewards: -168.722, net_loss: 3.129, number of most decision: 93, desicion tendecy: 93, eps: 0.05262
# =============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 29
#      26     done = 0
#      28 agent.memorize(state, action, idx, reward, next_state, done)
# ---> 29 loss = agent.run()
#      31 state = next_state
#      32 rewards += reward
#
# Cell In[13], line 74, in DQN_Agent.run(self)
#      71     return 1
#      73 states, actions, action_indexs, rewards, next_states, dones = self.convert_memory_to_input()
# ---> 74 loss = self.learn(states, actions, action_indexs, rewards, next_states, dones)
#      76 return loss.numpy()
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\ProgramData\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(rewards_hist)
