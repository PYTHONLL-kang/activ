# %%
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from collections import deque
import random as rand
import math
import matplotlib.pyplot as plt

# %%
np.set_printoptions(precision=6, suppress=True)

# %%
dnn_model = tf.keras.models.load_model('dnn.h5')

# %%
EPS_START = 0.9
EPS_END = 0.01
EPS_DECAY = 200

GAMMA = 0.8
batch_size = 1
episode_done = 2000

# %%
df = pd.read_excel('aug_nine_var.xlsx').iloc[:,1:22]
scaler = MinMaxScaler()
X = scaler.fit_transform(df)

# %%
def return_latest():
    df = pd.read_excel('aug_nine_var.xlsx').iloc[:,1:22]
    transform = scaler.transform(df)
    return transform[-1]

# %%
def return_state(action, state):
    if action % 2 == 0:
        value = -0.01
    
    else:
        value = 0.01

    j = int(action / 2)
    
    state[0][j] = state[0][j] + value
    next_state = state

    return next_state

# %%
def return_reward(state, y_pred):
    real_state = return_latest().reshape(1, 21)
    dist = np.sqrt(np.sum(np.square(real_state-state)))

    return dist*10 + y_pred

# %%
class Dqn_agent:
    def __init__(self):
        self.target = self._create_model()
        self.model = self._create_model()

        self.target.set_weights(self.model.get_weights())

        self.memory = deque(maxlen=10000)
        
    def _create_model(self):
        model = tf.keras.models.Sequential()
        model.add(tf.keras.layers.Dense(10, input_shape=(21, ), activation='relu'))
        model.add(tf.keras.layers.Dense(10, activation='relu'))
        model.add(tf.keras.layers.Dense(10, activation='relu'))
        model.add(tf.keras.layers.Dense(42, activation='linear'))

        model.compile(optimizer='rmsprop', loss='mse')

        return model

    def forward(self, x):
        x = self.model(x)
        return x
    
    def memorize(self, state, action, reward, next_state):
        self.memory.append((
            state, action,
            tf.cast(reward, tf.float16), next_state
        ))

    def act(self, state, episode):
        eps_threshold = EPS_END + ((EPS_START - EPS_END) * math.exp(-1 * episode / EPS_DECAY))
        if rand.random() > eps_threshold:
            return np.argmin(self.forward(state))
        else:
            return tf.convert_to_tensor([rand.randrange(42)])

    def learn(self, episode):
        if len(self.memory) < batch_size:
            return

        if episode % 10:
            self.target.set_weights(self.model.get_weights())

        batch = rand.sample(self.memory, batch_size)
        states, actions, rewards, next_states = zip(*batch)

        states = tf.convert_to_tensor(states[0]) # (batch_size, 21)
        actions = tf.convert_to_tensor(actions[0]) # (batch_size, )
        rewards = tf.convert_to_tensor(rewards[0]) # (batch_size, )
        next_states = tf.convert_to_tensor(next_states[0]) # (batch_size, 21)

        if actions.shape != (batch_size, ):
            actions = [actions]

        current_q = self.model.predict(states, verbose=0)
        next_q = self.target.predict(next_states, verbose=0)

        for i in range(batch_size):
            if episode == episode_done:
                next_q_value = rewards[i]
            else:
                next_q_value = rewards[i] + GAMMA * np.min(next_q[i])
            
            current_q[i][actions[i]] = next_q_value

        self.model.fit(states, current_q, batch_size=batch_size, verbose=False)

# %%
agent = Dqn_agent()
sc_hist = []
st_hist = []
pop_hist = []

for e in range(1, 200):
    state = return_latest()
    state = state.reshape(1, 21)
    steps = 0

    while True:
        pred_y = dnn_model.predict(state, verbose=0)

        action = agent.act(state, e)

        next_state = return_state(action, state)
        reward = return_reward(state, pred_y)

        agent.memorize(state, action, reward, next_state)
        agent.learn(e)

        state = next_state
        steps = steps + 1

        if steps % 10 == 0:
            print(f"steps: {steps}, reward: {reward}, pop: {int(pred_y)}")

        if steps == episode_done:
            print("=============episode done=============")
            print("episode: {0}, score: {2}, y_pred {3}".format(e, reward, pred_y))
            print("=======================================")
            sc_hist.append(reward)
            st_hist.append(scaler.inverse_transform(state))
            pop_hist.append(pred_y)
            break
# Out:
# steps: 10, reward: [[42.594475]], pop: 42
# steps: 20, reward: [[42.79346]], pop: 42
# steps: 30, reward: [[43.065323]], pop: 42
# steps: 40, reward: [[43.16742]], pop: 42
# steps: 50, reward: [[43.147964]], pop: 42
# steps: 60, reward: [[43.235397]], pop: 42
# steps: 70, reward: [[43.307888]], pop: 42
# steps: 80, reward: [[43.294895]], pop: 42
# steps: 90, reward: [[43.289486]], pop: 42
# steps: 100, reward: [[43.325176]], pop: 42
# steps: 110, reward: [[43.388985]], pop: 42
# steps: 120, reward: [[43.343697]], pop: 42
# steps: 130, reward: [[43.487823]], pop: 42
# steps: 140, reward: [[43.805286]], pop: 42
# steps: 150, reward: [[43.838566]], pop: 42
# steps: 160, reward: [[43.910053]], pop: 42
# steps: 170, reward: [[43.890915]], pop: 42
# steps: 180, reward: [[43.72577]], pop: 42
# steps: 190, reward: [[43.758232]], pop: 42
# steps: 200, reward: [[43.899258]], pop: 42
# steps: 210, reward: [[43.974613]], pop: 42
# steps: 220, reward: [[43.969257]], pop: 42
# steps: 230, reward: [[44.38039]], pop: 42
# steps: 240, reward: [[44.580086]], pop: 42
# steps: 250, reward: [[44.526096]], pop: 42
# steps: 260, reward: [[44.590935]], pop: 42
# steps: 270, reward: [[44.738415]], pop: 42
# steps: 280, reward: [[44.814594]], pop: 42
# steps: 290, reward: [[45.00851]], pop: 42
# steps: 300, reward: [[45.190105]], pop: 42
# steps: 310, reward: [[45.231976]], pop: 42
# steps: 320, reward: [[45.203804]], pop: 42
# steps: 330, reward: [[45.22339]], pop: 42
# steps: 340, reward: [[45.143543]], pop: 42
# steps: 350, reward: [[45.164864]], pop: 42
# steps: 360, reward: [[45.280064]], pop: 42
# steps: 370, reward: [[45.185127]], pop: 42
# steps: 380, reward: [[45.38479]], pop: 42
# steps: 390, reward: [[45.514736]], pop: 42
# steps: 400, reward: [[45.41179]], pop: 42
# steps: 410, reward: [[45.324562]], pop: 42
# steps: 420, reward: [[45.499374]], pop: 42
# steps: 430, reward: [[45.48282]], pop: 42
# steps: 440, reward: [[45.638786]], pop: 42
# steps: 450, reward: [[45.61099]], pop: 42
# steps: 460, reward: [[45.601498]], pop: 42
# steps: 470, reward: [[45.530514]], pop: 42
# steps: 480, reward: [[45.58757]], pop: 42
# steps: 490, reward: [[45.66847]], pop: 42
# steps: 500, reward: [[45.79171]], pop: 42
# steps: 510, reward: [[45.863037]], pop: 42
# steps: 520, reward: [[46.053387]], pop: 42
# steps: 530, reward: [[46.080505]], pop: 42
# steps: 540, reward: [[46.114475]], pop: 42
# steps: 550, reward: [[46.093098]], pop: 42
# steps: 560, reward: [[45.98095]], pop: 42
# steps: 570, reward: [[45.99794]], pop: 42
# steps: 580, reward: [[46.06022]], pop: 42
# steps: 590, reward: [[46.27926]], pop: 42
# steps: 600, reward: [[46.34594]], pop: 42
# steps: 610, reward: [[46.453094]], pop: 42
# steps: 620, reward: [[46.43828]], pop: 42
# steps: 630, reward: [[46.51597]], pop: 42
# steps: 640, reward: [[46.641457]], pop: 42
# steps: 650, reward: [[46.747974]], pop: 42
# steps: 660, reward: [[46.833324]], pop: 42
# steps: 670, reward: [[46.740463]], pop: 42
# steps: 680, reward: [[46.799797]], pop: 42
# steps: 690, reward: [[46.58314]], pop: 42
# steps: 700, reward: [[46.51586]], pop: 42
# steps: 710, reward: [[46.527542]], pop: 42
# steps: 720, reward: [[46.687115]], pop: 42
# steps: 730, reward: [[46.742474]], pop: 42
# steps: 740, reward: [[46.762283]], pop: 42
# steps: 750, reward: [[46.77825]], pop: 42
# steps: 760, reward: [[46.757885]], pop: 42
# steps: 770, reward: [[46.89219]], pop: 42
# steps: 780, reward: [[47.03594]], pop: 42
# steps: 790, reward: [[47.13446]], pop: 42
# steps: 800, reward: [[47.026802]], pop: 42
# steps: 810, reward: [[46.881413]], pop: 42
# steps: 820, reward: [[46.925735]], pop: 42
# steps: 830, reward: [[46.88848]], pop: 42
# steps: 840, reward: [[46.862194]], pop: 42
# steps: 850, reward: [[46.831905]], pop: 42
# steps: 860, reward: [[46.700996]], pop: 42
# steps: 870, reward: [[46.791855]], pop: 42
# steps: 880, reward: [[46.776814]], pop: 42
# steps: 890, reward: [[46.93913]], pop: 42
# steps: 900, reward: [[46.967422]], pop: 42
# steps: 910, reward: [[46.899296]], pop: 42
# steps: 920, reward: [[46.986748]], pop: 42
# steps: 930, reward: [[46.92796]], pop: 42
# steps: 940, reward: [[46.936314]], pop: 42
# steps: 950, reward: [[47.047512]], pop: 42
# steps: 960, reward: [[47.08721]], pop: 41
# steps: 970, reward: [[47.0745]], pop: 41
# steps: 980, reward: [[47.09745]], pop: 41
# steps: 990, reward: [[47.107357]], pop: 41
# steps: 1000, reward: [[46.923897]], pop: 41
# =============episode done=============
# episode: 1, y_pred: [[41.84256]], score: [[46.923897]]
# =======================================
# steps: 10, reward: [[42.689728]], pop: 42
# steps: 20, reward: [[42.92573]], pop: 42
# steps: 30, reward: [[43.049263]], pop: 42
# steps: 40, reward: [[43.09207]], pop: 42
# steps: 50, reward: [[43.13769]], pop: 42
# steps: 60, reward: [[43.233036]], pop: 42
# steps: 70, reward: [[43.32717]], pop: 42
# steps: 80, reward: [[43.369305]], pop: 42
# steps: 90, reward: [[43.714325]], pop: 42
# steps: 100, reward: [[43.88979]], pop: 42
# steps: 110, reward: [[43.94955]], pop: 42
# steps: 120, reward: [[43.988575]], pop: 42
# steps: 130, reward: [[44.108257]], pop: 42
# steps: 140, reward: [[44.11226]], pop: 42
# steps: 150, reward: [[44.103367]], pop: 42
# steps: 160, reward: [[44.125072]], pop: 41
# steps: 170, reward: [[44.04115]], pop: 41
# steps: 180, reward: [[44.111572]], pop: 41
# steps: 190, reward: [[44.06141]], pop: 41
# steps: 200, reward: [[44.08634]], pop: 41
# steps: 210, reward: [[44.184906]], pop: 41
# steps: 220, reward: [[44.19454]], pop: 41
# steps: 230, reward: [[44.28465]], pop: 41
# steps: 240, reward: [[44.421825]], pop: 41
# steps: 250, reward: [[44.36365]], pop: 41
# steps: 260, reward: [[44.202778]], pop: 41
# steps: 270, reward: [[44.25914]], pop: 41
# steps: 280, reward: [[44.24445]], pop: 41
# steps: 290, reward: [[44.252026]], pop: 41
# steps: 300, reward: [[44.20365]], pop: 41
# steps: 310, reward: [[44.170826]], pop: 41
# steps: 320, reward: [[44.203655]], pop: 41
# steps: 330, reward: [[44.126995]], pop: 41
# steps: 340, reward: [[44.16447]], pop: 41
# steps: 350, reward: [[44.226574]], pop: 41
# steps: 360, reward: [[44.307274]], pop: 41
# steps: 370, reward: [[44.36457]], pop: 41
# steps: 380, reward: [[44.514282]], pop: 41
# steps: 390, reward: [[44.469368]], pop: 41
# steps: 400, reward: [[44.53347]], pop: 41
# steps: 410, reward: [[44.494377]], pop: 41
# steps: 420, reward: [[44.637627]], pop: 41
# steps: 430, reward: [[44.70238]], pop: 41
# steps: 440, reward: [[44.611275]], pop: 41
# steps: 450, reward: [[44.588154]], pop: 41
# steps: 460, reward: [[44.591103]], pop: 41
# steps: 470, reward: [[44.756824]], pop: 41
# steps: 480, reward: [[44.73292]], pop: 41
# steps: 490, reward: [[44.743916]], pop: 41
# steps: 500, reward: [[44.826252]], pop: 41
# steps: 510, reward: [[44.790653]], pop: 41
# steps: 520, reward: [[44.775684]], pop: 41
# steps: 530, reward: [[44.855732]], pop: 41
# steps: 540, reward: [[45.0837]], pop: 41
# steps: 550, reward: [[45.141106]], pop: 41
# steps: 560, reward: [[45.200108]], pop: 41
# steps: 570, reward: [[45.28908]], pop: 41
# steps: 580, reward: [[45.4994]], pop: 41
# steps: 590, reward: [[45.64247]], pop: 41
# steps: 600, reward: [[45.76119]], pop: 41
# steps: 610, reward: [[46.01021]], pop: 41
# steps: 620, reward: [[46.070557]], pop: 41
# steps: 630, reward: [[46.202377]], pop: 41
# steps: 640, reward: [[46.36546]], pop: 41
# steps: 650, reward: [[46.41601]], pop: 41
# steps: 660, reward: [[46.49231]], pop: 41
# steps: 670, reward: [[46.504635]], pop: 41
# steps: 680, reward: [[46.521706]], pop: 41
# steps: 690, reward: [[46.514915]], pop: 41
# steps: 700, reward: [[46.59083]], pop: 41
# steps: 710, reward: [[46.621082]], pop: 41
# steps: 720, reward: [[46.65731]], pop: 41
# steps: 730, reward: [[46.67913]], pop: 41
# steps: 740, reward: [[46.689568]], pop: 41
# steps: 750, reward: [[46.720352]], pop: 41
# steps: 760, reward: [[46.515457]], pop: 41
# steps: 770, reward: [[46.519413]], pop: 41
# steps: 780, reward: [[46.646008]], pop: 41
# steps: 790, reward: [[46.746887]], pop: 41
# steps: 800, reward: [[46.74502]], pop: 41
# steps: 810, reward: [[46.79545]], pop: 41
# steps: 820, reward: [[46.84665]], pop: 41
# steps: 830, reward: [[46.94667]], pop: 41
# steps: 840, reward: [[47.017155]], pop: 41
# steps: 850, reward: [[47.173298]], pop: 41
# steps: 860, reward: [[47.09402]], pop: 41
# steps: 870, reward: [[47.024082]], pop: 41
# steps: 880, reward: [[46.998558]], pop: 41
# steps: 890, reward: [[47.064667]], pop: 41
# steps: 900, reward: [[47.028954]], pop: 41
# steps: 910, reward: [[47.02172]], pop: 41
# steps: 920, reward: [[47.051533]], pop: 41
# steps: 930, reward: [[46.948]], pop: 41
# steps: 940, reward: [[46.95867]], pop: 41
# steps: 950, reward: [[47.012062]], pop: 41
# steps: 960, reward: [[47.008484]], pop: 41
# steps: 970, reward: [[47.079796]], pop: 41
# steps: 980, reward: [[47.002697]], pop: 41
# steps: 990, reward: [[46.976006]], pop: 41
# steps: 1000, reward: [[47.005936]], pop: 41
# =============episode done=============
# episode: 2, y_pred: [[41.287544]], score: [[47.005936]]
# =======================================
# steps: 10, reward: [[42.654438]], pop: 42
# steps: 20, reward: [[42.785942]], pop: 42
# steps: 30, reward: [[43.000195]], pop: 42
# steps: 40, reward: [[43.253822]], pop: 42
# steps: 50, reward: [[43.329884]], pop: 42
# steps: 60, reward: [[43.306343]], pop: 42
# steps: 70, reward: [[43.412426]], pop: 42
# steps: 80, reward: [[43.45746]], pop: 42
# steps: 90, reward: [[43.4396]], pop: 42
# steps: 100, reward: [[43.66318]], pop: 42
# steps: 110, reward: [[43.823055]], pop: 42
# steps: 120, reward: [[43.81593]], pop: 42
# steps: 130, reward: [[43.910534]], pop: 42
# steps: 140, reward: [[44.152695]], pop: 42
# steps: 150, reward: [[44.047523]], pop: 42
# steps: 160, reward: [[44.308105]], pop: 42
# steps: 170, reward: [[44.302658]], pop: 42
# steps: 180, reward: [[44.434425]], pop: 42
# steps: 190, reward: [[44.469753]], pop: 42
# steps: 200, reward: [[44.49552]], pop: 42
# steps: 210, reward: [[44.53948]], pop: 42
# steps: 220, reward: [[44.60866]], pop: 42
# steps: 230, reward: [[44.710186]], pop: 42
# steps: 240, reward: [[44.637535]], pop: 42
# steps: 250, reward: [[44.646896]], pop: 42
# steps: 260, reward: [[44.73987]], pop: 42
# steps: 270, reward: [[44.910767]], pop: 42
# steps: 280, reward: [[44.907467]], pop: 42
# steps: 290, reward: [[45.031647]], pop: 42
# steps: 300, reward: [[44.99067]], pop: 42
# steps: 310, reward: [[45.00646]], pop: 42
# steps: 320, reward: [[45.171688]], pop: 42
# steps: 330, reward: [[45.20742]], pop: 42
# steps: 340, reward: [[45.295822]], pop: 42
# steps: 350, reward: [[45.542706]], pop: 42
# steps: 360, reward: [[45.51093]], pop: 42
# steps: 370, reward: [[45.574924]], pop: 42
# steps: 380, reward: [[45.657486]], pop: 42
# steps: 390, reward: [[45.711575]], pop: 42
# steps: 400, reward: [[45.76041]], pop: 42
# steps: 410, reward: [[45.6914]], pop: 42
# steps: 420, reward: [[45.62751]], pop: 42
# steps: 430, reward: [[45.695766]], pop: 42
# steps: 440, reward: [[45.648624]], pop: 42
# steps: 450, reward: [[45.879154]], pop: 42
# steps: 460, reward: [[45.982273]], pop: 42
# steps: 470, reward: [[46.15531]], pop: 42
# steps: 480, reward: [[46.292713]], pop: 42
# steps: 490, reward: [[46.51056]], pop: 42
# steps: 500, reward: [[46.53183]], pop: 42
# steps: 510, reward: [[46.625565]], pop: 42
# steps: 520, reward: [[46.62064]], pop: 42
# steps: 530, reward: [[46.58403]], pop: 42
# steps: 540, reward: [[46.594288]], pop: 42
# steps: 550, reward: [[46.64217]], pop: 42
# steps: 560, reward: [[46.839706]], pop: 42
# steps: 570, reward: [[46.90173]], pop: 42
# steps: 580, reward: [[46.99906]], pop: 42
# steps: 590, reward: [[46.90539]], pop: 42
# steps: 600, reward: [[46.83649]], pop: 42
# steps: 610, reward: [[46.794174]], pop: 42
# steps: 620, reward: [[46.81143]], pop: 42
# steps: 630, reward: [[46.687107]], pop: 42
# steps: 640, reward: [[46.7513]], pop: 42
# steps: 650, reward: [[46.888878]], pop: 42
# steps: 660, reward: [[46.930965]], pop: 42
# steps: 670, reward: [[46.88103]], pop: 42
# steps: 680, reward: [[46.950832]], pop: 42
# steps: 690, reward: [[46.9047]], pop: 42
# steps: 700, reward: [[46.983097]], pop: 42
# steps: 710, reward: [[47.087944]], pop: 42
# steps: 720, reward: [[47.076015]], pop: 42
# steps: 730, reward: [[47.01791]], pop: 42
# steps: 740, reward: [[47.16301]], pop: 42
# steps: 750, reward: [[47.21681]], pop: 42
# steps: 760, reward: [[47.223366]], pop: 42
# steps: 770, reward: [[47.209625]], pop: 42
# steps: 780, reward: [[47.22378]], pop: 42
# steps: 790, reward: [[47.2888]], pop: 42
# steps: 800, reward: [[47.37867]], pop: 42
# steps: 810, reward: [[47.542435]], pop: 42
# steps: 820, reward: [[47.577774]], pop: 41
# steps: 830, reward: [[47.5354]], pop: 41
# steps: 840, reward: [[47.573715]], pop: 41
# steps: 850, reward: [[47.494534]], pop: 41
# steps: 860, reward: [[47.67473]], pop: 41
# steps: 870, reward: [[47.638363]], pop: 41
# steps: 880, reward: [[47.563137]], pop: 41
# steps: 890, reward: [[47.50276]], pop: 41
# steps: 900, reward: [[47.42484]], pop: 41
# steps: 910, reward: [[47.441235]], pop: 41
# steps: 920, reward: [[47.450546]], pop: 42
# steps: 930, reward: [[47.54255]], pop: 42
# steps: 940, reward: [[47.64817]], pop: 42
# steps: 950, reward: [[47.599716]], pop: 42
# steps: 960, reward: [[47.655476]], pop: 42
# steps: 970, reward: [[47.701942]], pop: 42
# steps: 980, reward: [[47.68452]], pop: 42
# steps: 990, reward: [[47.455505]], pop: 42
# steps: 1000, reward: [[47.435707]], pop: 42
# =============episode done=============
# episode: 3, y_pred: [[42.095295]], score: [[47.435707]]
# =======================================
# steps: 10, reward: [[42.65887]], pop: 42
# steps: 20, reward: [[42.756542]], pop: 42
# steps: 30, reward: [[42.87529]], pop: 42
# steps: 40, reward: [[43.06608]], pop: 42
# steps: 50, reward: [[43.27392]], pop: 42
# steps: 60, reward: [[43.350426]], pop: 42
# steps: 70, reward: [[43.555313]], pop: 42
# steps: 80, reward: [[43.688576]], pop: 42
# steps: 90, reward: [[43.768547]], pop: 41
# steps: 100, reward: [[43.77671]], pop: 41
# steps: 110, reward: [[43.695934]], pop: 42
# steps: 120, reward: [[43.84937]], pop: 42
# steps: 130, reward: [[43.85687]], pop: 42
# steps: 140, reward: [[44.056854]], pop: 42
# steps: 150, reward: [[43.925488]], pop: 42
# steps: 160, reward: [[43.86477]], pop: 42
# steps: 170, reward: [[43.93218]], pop: 42
# steps: 180, reward: [[43.877796]], pop: 42
# steps: 190, reward: [[43.913902]], pop: 42
# steps: 200, reward: [[44.058582]], pop: 42
# steps: 210, reward: [[44.03526]], pop: 42
# steps: 220, reward: [[44.092342]], pop: 42
# steps: 230, reward: [[44.135437]], pop: 42
# steps: 240, reward: [[44.18142]], pop: 42
# steps: 250, reward: [[44.241028]], pop: 42
# steps: 260, reward: [[44.28309]], pop: 42
# steps: 270, reward: [[44.319653]], pop: 42
# steps: 280, reward: [[44.42591]], pop: 42
# steps: 290, reward: [[44.408203]], pop: 42
# steps: 300, reward: [[44.431892]], pop: 42
# steps: 310, reward: [[44.395184]], pop: 42
# steps: 320, reward: [[44.50337]], pop: 42
# steps: 330, reward: [[44.44468]], pop: 42
# steps: 340, reward: [[44.38995]], pop: 42
# steps: 350, reward: [[44.428253]], pop: 42
# steps: 360, reward: [[44.433636]], pop: 42
# steps: 370, reward: [[44.329056]], pop: 42
# steps: 380, reward: [[44.361366]], pop: 42
# steps: 390, reward: [[44.372784]], pop: 42
# steps: 400, reward: [[44.54567]], pop: 42
# steps: 410, reward: [[44.51756]], pop: 42
# steps: 420, reward: [[44.654877]], pop: 42
# steps: 430, reward: [[44.766075]], pop: 42
# steps: 440, reward: [[44.829365]], pop: 42
# steps: 450, reward: [[44.960815]], pop: 42
# steps: 460, reward: [[45.05472]], pop: 42
# steps: 470, reward: [[44.964745]], pop: 42
# steps: 480, reward: [[45.021435]], pop: 41
# steps: 490, reward: [[45.05626]], pop: 41
# steps: 500, reward: [[45.14783]], pop: 41
# steps: 510, reward: [[45.050575]], pop: 41
# steps: 520, reward: [[45.095825]], pop: 41
# steps: 530, reward: [[45.081825]], pop: 41
# steps: 540, reward: [[45.160427]], pop: 41
# steps: 550, reward: [[45.04256]], pop: 41
# steps: 560, reward: [[44.977848]], pop: 41
# steps: 570, reward: [[45.091274]], pop: 41
# steps: 580, reward: [[45.02867]], pop: 41
# steps: 590, reward: [[45.0203]], pop: 41
# steps: 600, reward: [[44.99424]], pop: 41
# steps: 610, reward: [[45.010437]], pop: 41
# steps: 620, reward: [[44.96135]], pop: 41
# steps: 630, reward: [[44.95214]], pop: 41
# steps: 640, reward: [[45.05226]], pop: 41
# steps: 650, reward: [[45.089226]], pop: 41
# steps: 660, reward: [[44.978386]], pop: 41
# steps: 670, reward: [[45.07248]], pop: 41
# steps: 680, reward: [[45.150513]], pop: 41
# steps: 690, reward: [[45.184795]], pop: 41
# steps: 700, reward: [[45.122936]], pop: 41
# steps: 710, reward: [[45.103497]], pop: 41
# steps: 720, reward: [[45.0465]], pop: 41
# steps: 730, reward: [[45.07472]], pop: 41
# steps: 740, reward: [[45.219723]], pop: 41
# steps: 750, reward: [[45.334377]], pop: 41
# steps: 760, reward: [[45.452312]], pop: 41
# steps: 770, reward: [[45.56851]], pop: 41
# steps: 780, reward: [[45.52136]], pop: 41
# steps: 790, reward: [[45.440166]], pop: 41
# steps: 800, reward: [[45.48135]], pop: 41
# steps: 810, reward: [[45.550224]], pop: 41
# steps: 820, reward: [[45.740547]], pop: 41
# steps: 830, reward: [[45.684376]], pop: 41
# steps: 840, reward: [[45.75134]], pop: 41
# steps: 850, reward: [[45.89078]], pop: 41
# steps: 860, reward: [[45.814514]], pop: 41
# steps: 870, reward: [[45.866966]], pop: 41
# steps: 880, reward: [[45.88538]], pop: 41
# steps: 890, reward: [[46.037437]], pop: 41
# steps: 900, reward: [[46.108963]], pop: 41
# steps: 910, reward: [[46.13574]], pop: 41
# steps: 920, reward: [[46.127388]], pop: 41
# steps: 930, reward: [[46.208256]], pop: 41
# steps: 940, reward: [[46.2709]], pop: 41
# steps: 950, reward: [[46.29492]], pop: 41
# steps: 960, reward: [[46.272064]], pop: 41
# steps: 970, reward: [[46.492565]], pop: 41
# steps: 980, reward: [[46.542625]], pop: 41
# steps: 990, reward: [[46.564095]], pop: 41
# steps: 1000, reward: [[46.636497]], pop: 41
# =============episode done=============
# episode: 4, y_pred: [[41.832333]], score: [[46.636497]]
# =======================================
# steps: 10, reward: [[42.579674]], pop: 42
# steps: 20, reward: [[42.685345]], pop: 42
# steps: 30, reward: [[42.808132]], pop: 42
# steps: 40, reward: [[42.93789]], pop: 42
# steps: 50, reward: [[42.895317]], pop: 42
# steps: 60, reward: [[43.02321]], pop: 42
# steps: 70, reward: [[43.06643]], pop: 42
# steps: 80, reward: [[43.11767]], pop: 42
# steps: 90, reward: [[43.222992]], pop: 42
# steps: 100, reward: [[43.383087]], pop: 42
# steps: 110, reward: [[43.3566]], pop: 42
# steps: 120, reward: [[43.428535]], pop: 42
# steps: 130, reward: [[43.464607]], pop: 42
# steps: 140, reward: [[43.571606]], pop: 42
# steps: 150, reward: [[43.470474]], pop: 42
# steps: 160, reward: [[43.523098]], pop: 42
# steps: 170, reward: [[43.71113]], pop: 42
# steps: 180, reward: [[43.76342]], pop: 42
# steps: 190, reward: [[43.805943]], pop: 42
# steps: 200, reward: [[43.883892]], pop: 42
# steps: 210, reward: [[43.908417]], pop: 42
# steps: 220, reward: [[44.121708]], pop: 42
# steps: 230, reward: [[43.972748]], pop: 42
# steps: 240, reward: [[43.868355]], pop: 42
# steps: 250, reward: [[43.911167]], pop: 42
# steps: 260, reward: [[44.180447]], pop: 42
# steps: 270, reward: [[44.306824]], pop: 42
# steps: 280, reward: [[44.343933]], pop: 42
# steps: 290, reward: [[44.536934]], pop: 42
# steps: 300, reward: [[44.55045]], pop: 42
# steps: 310, reward: [[44.63968]], pop: 42
# steps: 320, reward: [[44.689186]], pop: 42
# steps: 330, reward: [[44.745235]], pop: 42
# steps: 340, reward: [[44.839905]], pop: 42
# steps: 350, reward: [[44.9463]], pop: 42
# steps: 360, reward: [[45.185085]], pop: 42
# steps: 370, reward: [[45.179623]], pop: 42
# steps: 380, reward: [[45.157524]], pop: 42
# steps: 390, reward: [[45.165764]], pop: 42
# steps: 400, reward: [[45.241787]], pop: 42
# steps: 410, reward: [[45.361378]], pop: 42
# steps: 420, reward: [[45.623505]], pop: 42
# steps: 430, reward: [[45.660374]], pop: 42
# steps: 440, reward: [[45.820953]], pop: 43
# steps: 450, reward: [[45.90913]], pop: 43
# steps: 460, reward: [[45.84326]], pop: 42
# steps: 470, reward: [[45.74047]], pop: 42
# steps: 480, reward: [[45.812817]], pop: 42
# steps: 490, reward: [[45.662315]], pop: 42
# steps: 500, reward: [[45.79234]], pop: 42
# steps: 510, reward: [[45.6938]], pop: 42
# steps: 520, reward: [[45.77112]], pop: 42
# steps: 530, reward: [[45.63198]], pop: 42
# steps: 540, reward: [[45.758865]], pop: 42
# steps: 550, reward: [[45.447502]], pop: 42
# steps: 560, reward: [[45.469826]], pop: 42
# steps: 570, reward: [[45.564606]], pop: 42
# steps: 580, reward: [[45.6687]], pop: 42
# steps: 590, reward: [[45.653645]], pop: 42
# steps: 600, reward: [[45.679108]], pop: 42
# steps: 610, reward: [[45.57395]], pop: 42
# steps: 620, reward: [[45.610218]], pop: 42
# steps: 630, reward: [[45.683674]], pop: 42
# steps: 640, reward: [[45.630856]], pop: 42
# steps: 650, reward: [[45.75567]], pop: 42
# steps: 660, reward: [[45.873077]], pop: 42
# steps: 670, reward: [[45.890305]], pop: 42
# steps: 680, reward: [[45.974167]], pop: 42
# steps: 690, reward: [[46.098164]], pop: 42
# steps: 700, reward: [[46.017815]], pop: 42
# steps: 710, reward: [[46.127945]], pop: 42
# steps: 720, reward: [[46.08347]], pop: 42
# steps: 730, reward: [[46.002213]], pop: 42
# steps: 740, reward: [[46.010777]], pop: 42
# steps: 750, reward: [[46.097626]], pop: 42
# steps: 760, reward: [[46.083702]], pop: 42
# steps: 770, reward: [[46.155403]], pop: 42
# steps: 780, reward: [[46.196377]], pop: 42
# steps: 790, reward: [[46.381084]], pop: 42
# steps: 800, reward: [[46.52339]], pop: 42
# steps: 810, reward: [[46.557518]], pop: 42
# steps: 820, reward: [[46.647247]], pop: 42
# steps: 830, reward: [[46.55041]], pop: 42
# steps: 840, reward: [[46.534626]], pop: 42
# steps: 850, reward: [[46.514305]], pop: 42
# steps: 860, reward: [[46.50307]], pop: 42
# steps: 870, reward: [[46.419586]], pop: 42
# steps: 880, reward: [[46.37838]], pop: 42
# steps: 890, reward: [[46.377056]], pop: 42
# steps: 900, reward: [[46.330345]], pop: 42
# steps: 910, reward: [[46.245125]], pop: 42
# steps: 920, reward: [[46.316616]], pop: 42
# steps: 930, reward: [[46.609608]], pop: 42
# steps: 940, reward: [[46.704697]], pop: 42
# steps: 950, reward: [[46.564304]], pop: 42
# steps: 960, reward: [[46.695045]], pop: 42
# steps: 970, reward: [[46.74344]], pop: 42
# steps: 980, reward: [[46.793686]], pop: 42
# steps: 990, reward: [[47.015297]], pop: 42
# steps: 1000, reward: [[46.913277]], pop: 42
# =============episode done=============
# episode: 5, y_pred: [[42.856182]], score: [[46.913277]]
# =======================================
# steps: 10, reward: [[42.62512]], pop: 42
# steps: 20, reward: [[42.73399]], pop: 42
# steps: 30, reward: [[43.01229]], pop: 42
# steps: 40, reward: [[43.104794]], pop: 42
# steps: 50, reward: [[43.238976]], pop: 42
# steps: 60, reward: [[43.22873]], pop: 42
# steps: 70, reward: [[43.22362]], pop: 42
# steps: 80, reward: [[43.248886]], pop: 42
# steps: 90, reward: [[43.39353]], pop: 42
# steps: 100, reward: [[43.458134]], pop: 42
# steps: 110, reward: [[43.636715]], pop: 42
# steps: 120, reward: [[43.779625]], pop: 42
# steps: 130, reward: [[43.993763]], pop: 42
# steps: 140, reward: [[44.06135]], pop: 42
# steps: 150, reward: [[44.01375]], pop: 42
# steps: 160, reward: [[44.089375]], pop: 42
# steps: 170, reward: [[44.062176]], pop: 42
# steps: 180, reward: [[44.204994]], pop: 42
# steps: 190, reward: [[44.604416]], pop: 42
# steps: 200, reward: [[44.65399]], pop: 42
# steps: 210, reward: [[44.677856]], pop: 42
# steps: 220, reward: [[44.520428]], pop: 42
# steps: 230, reward: [[44.518143]], pop: 42
# steps: 240, reward: [[44.844917]], pop: 42
# steps: 250, reward: [[44.938778]], pop: 42
# steps: 260, reward: [[44.970024]], pop: 42
# steps: 270, reward: [[44.84826]], pop: 42
# steps: 280, reward: [[44.948452]], pop: 42
# steps: 290, reward: [[44.87078]], pop: 42
# steps: 300, reward: [[44.821445]], pop: 41
# steps: 310, reward: [[44.863224]], pop: 41
# steps: 320, reward: [[44.80512]], pop: 41
# steps: 330, reward: [[44.776047]], pop: 41
# steps: 340, reward: [[44.77652]], pop: 41
# steps: 350, reward: [[44.836403]], pop: 41
# steps: 360, reward: [[44.913677]], pop: 41
# steps: 370, reward: [[45.01461]], pop: 41
# steps: 380, reward: [[45.052025]], pop: 41
# steps: 390, reward: [[45.103096]], pop: 41
# steps: 400, reward: [[45.167046]], pop: 41
# steps: 410, reward: [[45.14906]], pop: 41
# steps: 420, reward: [[45.400146]], pop: 41
# steps: 430, reward: [[45.452244]], pop: 41
# steps: 440, reward: [[45.538975]], pop: 41
# steps: 450, reward: [[45.6199]], pop: 41
# steps: 460, reward: [[45.517036]], pop: 41
# steps: 470, reward: [[45.546265]], pop: 41
# steps: 480, reward: [[45.49066]], pop: 41
# steps: 490, reward: [[45.49962]], pop: 41
# steps: 500, reward: [[45.51186]], pop: 41
# steps: 510, reward: [[45.441532]], pop: 41
# steps: 520, reward: [[45.486042]], pop: 42
# steps: 530, reward: [[45.527874]], pop: 42
# steps: 540, reward: [[45.47186]], pop: 42
# steps: 550, reward: [[45.636604]], pop: 42
# steps: 560, reward: [[45.739773]], pop: 42
# steps: 570, reward: [[45.732155]], pop: 42
# steps: 580, reward: [[45.684574]], pop: 42
# steps: 590, reward: [[45.619843]], pop: 42
# steps: 600, reward: [[45.567814]], pop: 42
# steps: 610, reward: [[45.66227]], pop: 41
# steps: 620, reward: [[45.689953]], pop: 41
# steps: 630, reward: [[45.59263]], pop: 41
# steps: 640, reward: [[45.69593]], pop: 41
# steps: 650, reward: [[45.734726]], pop: 41
# steps: 660, reward: [[45.677296]], pop: 41
# steps: 670, reward: [[45.74194]], pop: 41
# steps: 680, reward: [[45.84206]], pop: 41
# steps: 690, reward: [[45.943405]], pop: 41
# steps: 700, reward: [[46.10326]], pop: 41
# steps: 710, reward: [[46.425915]], pop: 41
# steps: 720, reward: [[46.50244]], pop: 41
# steps: 730, reward: [[46.336185]], pop: 41
# steps: 740, reward: [[46.350384]], pop: 41
# steps: 750, reward: [[46.4071]], pop: 41
# steps: 760, reward: [[46.461693]], pop: 41
# steps: 770, reward: [[46.58104]], pop: 41
# steps: 780, reward: [[46.62486]], pop: 41
# steps: 790, reward: [[46.58784]], pop: 41
# steps: 800, reward: [[46.561405]], pop: 41
# steps: 810, reward: [[46.642662]], pop: 41
# steps: 820, reward: [[46.51912]], pop: 41
# steps: 830, reward: [[46.548435]], pop: 41
# steps: 840, reward: [[46.706482]], pop: 41
# steps: 850, reward: [[46.634895]], pop: 41
# steps: 860, reward: [[46.554787]], pop: 41
# steps: 870, reward: [[46.530212]], pop: 41
# steps: 880, reward: [[46.48327]], pop: 41
# steps: 890, reward: [[46.481842]], pop: 41
# steps: 900, reward: [[46.372738]], pop: 41
# steps: 910, reward: [[46.407692]], pop: 41
# steps: 920, reward: [[46.524162]], pop: 41
# steps: 930, reward: [[46.59143]], pop: 41
# steps: 940, reward: [[46.529793]], pop: 41
# steps: 950, reward: [[46.347878]], pop: 41
# steps: 960, reward: [[46.21109]], pop: 41
# steps: 970, reward: [[46.24054]], pop: 41
# steps: 980, reward: [[46.167397]], pop: 41
# steps: 990, reward: [[46.132965]], pop: 41
# steps: 1000, reward: [[46.23921]], pop: 41
# =============episode done=============
# episode: 6, y_pred: [[41.514805]], score: [[46.23921]]
# =======================================
# steps: 10, reward: [[42.709717]], pop: 42
# steps: 20, reward: [[43.102974]], pop: 42
# steps: 30, reward: [[43.177155]], pop: 42
# steps: 40, reward: [[43.08167]], pop: 42
# steps: 50, reward: [[43.227726]], pop: 42
# steps: 60, reward: [[43.45145]], pop: 42
# steps: 70, reward: [[43.39532]], pop: 42
# steps: 80, reward: [[43.58332]], pop: 42
# steps: 90, reward: [[43.77001]], pop: 42
# steps: 100, reward: [[43.92724]], pop: 42
# steps: 110, reward: [[43.971138]], pop: 42
# steps: 120, reward: [[44.12667]], pop: 42
# steps: 130, reward: [[44.27705]], pop: 42
# steps: 140, reward: [[44.271202]], pop: 42
# steps: 150, reward: [[44.32519]], pop: 42
# steps: 160, reward: [[44.29804]], pop: 42
# steps: 170, reward: [[44.336517]], pop: 42
# steps: 180, reward: [[44.444786]], pop: 42
# steps: 190, reward: [[44.572845]], pop: 42
# steps: 200, reward: [[44.540527]], pop: 42
# steps: 210, reward: [[44.50773]], pop: 42
# steps: 220, reward: [[44.553146]], pop: 42
# steps: 230, reward: [[44.682537]], pop: 42
# steps: 240, reward: [[44.816216]], pop: 42
# steps: 250, reward: [[44.665306]], pop: 42
# steps: 260, reward: [[44.727657]], pop: 42
# steps: 270, reward: [[44.682426]], pop: 42
# steps: 280, reward: [[44.638992]], pop: 42
# steps: 290, reward: [[44.791466]], pop: 42
# steps: 300, reward: [[44.887234]], pop: 42
# steps: 310, reward: [[44.997684]], pop: 42
# steps: 320, reward: [[45.020336]], pop: 42
# steps: 330, reward: [[45.074223]], pop: 42
# steps: 340, reward: [[45.13864]], pop: 42
# steps: 350, reward: [[44.975533]], pop: 42
# steps: 360, reward: [[44.91399]], pop: 42
# steps: 370, reward: [[44.910534]], pop: 42
# steps: 380, reward: [[44.973896]], pop: 42
# steps: 390, reward: [[45.059982]], pop: 42
# steps: 400, reward: [[45.03161]], pop: 42
# steps: 410, reward: [[44.993214]], pop: 42
# steps: 420, reward: [[44.95654]], pop: 42
# steps: 430, reward: [[44.91109]], pop: 42
# steps: 440, reward: [[45.07465]], pop: 42
# steps: 450, reward: [[45.20087]], pop: 42
# steps: 460, reward: [[45.3757]], pop: 42
# steps: 470, reward: [[45.29928]], pop: 42
# steps: 480, reward: [[45.334328]], pop: 42
# steps: 490, reward: [[45.277733]], pop: 42
# steps: 500, reward: [[45.304897]], pop: 42
# steps: 510, reward: [[45.3836]], pop: 42
# steps: 520, reward: [[45.510876]], pop: 42
# steps: 530, reward: [[45.733536]], pop: 42
# steps: 540, reward: [[45.803535]], pop: 43
# steps: 550, reward: [[45.614017]], pop: 42
# steps: 560, reward: [[45.625233]], pop: 42
# steps: 570, reward: [[45.597813]], pop: 42
# steps: 580, reward: [[45.70002]], pop: 42
# steps: 590, reward: [[45.853542]], pop: 42
# steps: 600, reward: [[45.936573]], pop: 42
# steps: 610, reward: [[46.0545]], pop: 42
# steps: 620, reward: [[46.1115]], pop: 42
# steps: 630, reward: [[46.169937]], pop: 42
# steps: 640, reward: [[46.12348]], pop: 42
# steps: 650, reward: [[45.954918]], pop: 42
# steps: 660, reward: [[45.934868]], pop: 42
# steps: 670, reward: [[45.970684]], pop: 42
# steps: 680, reward: [[45.894474]], pop: 42
# steps: 690, reward: [[46.14128]], pop: 43
# steps: 700, reward: [[46.32619]], pop: 43
# steps: 710, reward: [[46.426453]], pop: 43
# steps: 720, reward: [[46.489464]], pop: 43
# steps: 730, reward: [[46.654083]], pop: 43
# steps: 740, reward: [[46.713894]], pop: 43
# steps: 750, reward: [[46.912174]], pop: 43
# steps: 760, reward: [[47.040466]], pop: 43
# steps: 770, reward: [[46.905422]], pop: 43
# steps: 780, reward: [[46.87175]], pop: 43
# steps: 790, reward: [[46.90362]], pop: 43
# steps: 800, reward: [[46.833973]], pop: 43
# steps: 810, reward: [[46.819973]], pop: 43
# steps: 820, reward: [[46.85606]], pop: 43
# steps: 830, reward: [[46.63067]], pop: 43
# steps: 840, reward: [[46.70885]], pop: 43
# steps: 850, reward: [[46.726578]], pop: 43
# steps: 860, reward: [[46.746437]], pop: 43
# steps: 870, reward: [[46.663074]], pop: 43
# steps: 880, reward: [[46.747868]], pop: 43
# steps: 890, reward: [[46.799946]], pop: 43
# steps: 900, reward: [[46.785686]], pop: 43
# steps: 910, reward: [[46.83749]], pop: 43
# steps: 920, reward: [[46.93477]], pop: 43
# steps: 930, reward: [[46.982674]], pop: 43
# steps: 940, reward: [[46.96039]], pop: 43
# steps: 950, reward: [[46.91996]], pop: 43
# steps: 960, reward: [[46.809372]], pop: 43
# steps: 970, reward: [[46.757294]], pop: 43
# steps: 980, reward: [[46.86914]], pop: 43
# steps: 990, reward: [[46.8989]], pop: 43
# steps: 1000, reward: [[47.045883]], pop: 43
# =============episode done=============
# episode: 7, y_pred: [[43.57313]], score: [[47.045883]]
# =======================================
# steps: 10, reward: [[42.61182]], pop: 42
# steps: 20, reward: [[42.79256]], pop: 42
# steps: 30, reward: [[42.981796]], pop: 42
# steps: 40, reward: [[43.1016]], pop: 42
# steps: 50, reward: [[43.16175]], pop: 42
# steps: 60, reward: [[43.423122]], pop: 42
# steps: 70, reward: [[43.526627]], pop: 42
# steps: 80, reward: [[43.657204]], pop: 42
# steps: 90, reward: [[43.679466]], pop: 42
# steps: 100, reward: [[44.04325]], pop: 42
# steps: 110, reward: [[44.195995]], pop: 42
# steps: 120, reward: [[44.274704]], pop: 42
# steps: 130, reward: [[44.480488]], pop: 42
# steps: 140, reward: [[44.66557]], pop: 42
# steps: 150, reward: [[44.827446]], pop: 42
# steps: 160, reward: [[44.854797]], pop: 42
# steps: 170, reward: [[44.86604]], pop: 42
# steps: 180, reward: [[45.05221]], pop: 42
# steps: 190, reward: [[44.994633]], pop: 42
# steps: 200, reward: [[44.952457]], pop: 42
# steps: 210, reward: [[45.103672]], pop: 42
# steps: 220, reward: [[45.05525]], pop: 42
# steps: 230, reward: [[45.128662]], pop: 42
# steps: 240, reward: [[45.360565]], pop: 42
# steps: 250, reward: [[45.502434]], pop: 42
# steps: 260, reward: [[45.48779]], pop: 42
# steps: 270, reward: [[45.530075]], pop: 42
# steps: 280, reward: [[45.516933]], pop: 42
# steps: 290, reward: [[45.588955]], pop: 42
# steps: 300, reward: [[45.667633]], pop: 42
# steps: 310, reward: [[45.71418]], pop: 42
# steps: 320, reward: [[45.74007]], pop: 42
# steps: 330, reward: [[45.655396]], pop: 42
# steps: 340, reward: [[45.72828]], pop: 42
# steps: 350, reward: [[45.82602]], pop: 42
# steps: 360, reward: [[45.8192]], pop: 42
# steps: 370, reward: [[45.931763]], pop: 42
# steps: 380, reward: [[45.945316]], pop: 42
# steps: 390, reward: [[45.919865]], pop: 42
# steps: 400, reward: [[45.96723]], pop: 42
# steps: 410, reward: [[45.94961]], pop: 42
# steps: 420, reward: [[45.96235]], pop: 42
# steps: 430, reward: [[45.942337]], pop: 42
# steps: 440, reward: [[45.922665]], pop: 42
# steps: 450, reward: [[46.03628]], pop: 42
# steps: 460, reward: [[46.18493]], pop: 42
# steps: 470, reward: [[46.166836]], pop: 42
# steps: 480, reward: [[46.1765]], pop: 42
# steps: 490, reward: [[46.260418]], pop: 42
# steps: 500, reward: [[46.361156]], pop: 42
# steps: 510, reward: [[46.41813]], pop: 42
# steps: 520, reward: [[46.35648]], pop: 42
# steps: 530, reward: [[46.362476]], pop: 42
# steps: 540, reward: [[46.403465]], pop: 42
# steps: 550, reward: [[46.468864]], pop: 42
# steps: 560, reward: [[46.48866]], pop: 42
# steps: 570, reward: [[46.507748]], pop: 42
# steps: 580, reward: [[46.49619]], pop: 42
# steps: 590, reward: [[46.350155]], pop: 42
# steps: 600, reward: [[46.290703]], pop: 42
# steps: 610, reward: [[46.234623]], pop: 42
# steps: 620, reward: [[46.291893]], pop: 42
# steps: 630, reward: [[46.252323]], pop: 42
# steps: 640, reward: [[46.286396]], pop: 42
# steps: 650, reward: [[46.332714]], pop: 42
# steps: 660, reward: [[46.34216]], pop: 42
# steps: 670, reward: [[46.357994]], pop: 42
# steps: 680, reward: [[46.33534]], pop: 42
# steps: 690, reward: [[46.187504]], pop: 42
# steps: 700, reward: [[46.30102]], pop: 42
# steps: 710, reward: [[46.370884]], pop: 42
# steps: 720, reward: [[46.547703]], pop: 42
# steps: 730, reward: [[46.644123]], pop: 42
# steps: 740, reward: [[46.689335]], pop: 42
# steps: 750, reward: [[46.745358]], pop: 42
# steps: 760, reward: [[46.669605]], pop: 42
# steps: 770, reward: [[46.82702]], pop: 42
# steps: 780, reward: [[46.939713]], pop: 42
# steps: 790, reward: [[46.98172]], pop: 42
# steps: 800, reward: [[47.085133]], pop: 43
# steps: 810, reward: [[47.086784]], pop: 43
# steps: 820, reward: [[46.895817]], pop: 42
# steps: 830, reward: [[46.738163]], pop: 42
# steps: 840, reward: [[46.74841]], pop: 42
# steps: 850, reward: [[46.700924]], pop: 42
# steps: 860, reward: [[46.6917]], pop: 42
# steps: 870, reward: [[46.76343]], pop: 43
# steps: 880, reward: [[46.96833]], pop: 43
# steps: 890, reward: [[46.950405]], pop: 43
# steps: 900, reward: [[46.878975]], pop: 43
# steps: 910, reward: [[46.782925]], pop: 43
# steps: 920, reward: [[46.84656]], pop: 43
# steps: 930, reward: [[46.702843]], pop: 43
# steps: 940, reward: [[46.71881]], pop: 43
# steps: 950, reward: [[46.597095]], pop: 43
# steps: 960, reward: [[46.487114]], pop: 43
# steps: 970, reward: [[46.556416]], pop: 43
# steps: 980, reward: [[46.508133]], pop: 43
# steps: 990, reward: [[46.74202]], pop: 43
# steps: 1000, reward: [[46.861298]], pop: 43
# =============episode done=============
# episode: 8, y_pred: [[43.19251]], score: [[46.861298]]
# =======================================
# steps: 10, reward: [[42.601677]], pop: 42
# steps: 20, reward: [[42.74354]], pop: 42
# steps: 30, reward: [[42.777103]], pop: 42
# steps: 40, reward: [[42.927837]], pop: 42
# steps: 50, reward: [[43.114372]], pop: 42
# steps: 60, reward: [[43.158695]], pop: 42
# steps: 70, reward: [[43.296608]], pop: 42
# steps: 80, reward: [[43.30613]], pop: 42
# steps: 90, reward: [[43.377907]], pop: 42
# steps: 100, reward: [[43.346256]], pop: 42
# steps: 110, reward: [[43.45829]], pop: 42
# steps: 120, reward: [[43.498924]], pop: 42
# steps: 130, reward: [[43.58416]], pop: 42
# steps: 140, reward: [[43.596172]], pop: 42
# steps: 150, reward: [[43.734116]], pop: 42
# steps: 160, reward: [[43.869778]], pop: 42
# steps: 170, reward: [[43.997353]], pop: 42
# steps: 180, reward: [[44.014748]], pop: 42
# steps: 190, reward: [[44.16209]], pop: 42
# steps: 200, reward: [[44.27299]], pop: 42
# steps: 210, reward: [[44.43664]], pop: 42
# steps: 220, reward: [[44.388336]], pop: 42
# steps: 230, reward: [[44.4916]], pop: 42
# steps: 240, reward: [[44.638237]], pop: 42
# steps: 250, reward: [[44.730717]], pop: 42
# steps: 260, reward: [[44.719944]], pop: 42
# steps: 270, reward: [[44.72277]], pop: 42
# steps: 280, reward: [[44.867783]], pop: 42
# steps: 290, reward: [[44.90821]], pop: 42
# steps: 300, reward: [[45.106903]], pop: 42
# steps: 310, reward: [[45.100708]], pop: 42
# steps: 320, reward: [[45.13119]], pop: 42
# steps: 330, reward: [[45.260773]], pop: 42
# steps: 340, reward: [[45.153313]], pop: 42
# steps: 350, reward: [[45.034584]], pop: 42
# steps: 360, reward: [[44.999863]], pop: 42
# steps: 370, reward: [[45.01568]], pop: 42
# steps: 380, reward: [[44.98198]], pop: 42
# steps: 390, reward: [[45.032032]], pop: 42
# steps: 400, reward: [[45.13834]], pop: 42
# steps: 410, reward: [[45.112522]], pop: 42
# steps: 420, reward: [[45.058453]], pop: 42
# steps: 430, reward: [[45.07553]], pop: 42
# steps: 440, reward: [[45.11527]], pop: 42
# steps: 450, reward: [[45.196766]], pop: 42
# steps: 460, reward: [[45.32875]], pop: 42
# steps: 470, reward: [[45.324886]], pop: 42
# steps: 480, reward: [[45.294167]], pop: 41
# steps: 490, reward: [[45.30364]], pop: 41
# steps: 500, reward: [[45.295437]], pop: 41
# steps: 510, reward: [[45.303574]], pop: 41
# steps: 520, reward: [[45.30508]], pop: 41
# steps: 530, reward: [[45.33637]], pop: 41
# steps: 540, reward: [[45.406517]], pop: 41
# steps: 550, reward: [[45.49585]], pop: 41
# steps: 560, reward: [[45.53359]], pop: 41
# steps: 570, reward: [[45.582787]], pop: 42
# steps: 580, reward: [[45.616165]], pop: 42
# steps: 590, reward: [[45.599186]], pop: 42
# steps: 600, reward: [[45.56846]], pop: 42
# steps: 610, reward: [[45.725956]], pop: 42
# steps: 620, reward: [[45.843536]], pop: 42
# steps: 630, reward: [[45.978683]], pop: 42
# steps: 640, reward: [[46.267525]], pop: 42
# steps: 650, reward: [[46.265076]], pop: 42
# steps: 660, reward: [[46.301235]], pop: 42
# steps: 670, reward: [[46.15396]], pop: 42
# steps: 680, reward: [[45.969143]], pop: 42
# steps: 690, reward: [[45.892563]], pop: 42
# steps: 700, reward: [[45.970848]], pop: 42
# steps: 710, reward: [[45.86598]], pop: 42
# steps: 720, reward: [[45.778843]], pop: 42
# steps: 730, reward: [[45.774822]], pop: 42
# steps: 740, reward: [[45.82682]], pop: 42
# steps: 750, reward: [[45.81022]], pop: 42
# steps: 760, reward: [[45.828655]], pop: 41
# steps: 770, reward: [[45.8448]], pop: 41
# steps: 780, reward: [[45.80823]], pop: 41
# steps: 790, reward: [[45.7471]], pop: 41
# steps: 800, reward: [[45.665123]], pop: 41
# steps: 810, reward: [[45.60653]], pop: 41
# steps: 820, reward: [[45.605137]], pop: 41
# steps: 830, reward: [[45.47097]], pop: 41
# steps: 840, reward: [[45.436234]], pop: 41
# steps: 850, reward: [[45.437195]], pop: 41
# steps: 860, reward: [[45.542923]], pop: 41
# steps: 870, reward: [[45.620728]], pop: 41
# steps: 880, reward: [[45.69617]], pop: 41
# steps: 890, reward: [[45.753174]], pop: 41
# steps: 900, reward: [[45.731915]], pop: 41
# steps: 910, reward: [[45.810085]], pop: 41
# steps: 920, reward: [[45.826614]], pop: 41
# steps: 930, reward: [[45.829926]], pop: 41
# steps: 940, reward: [[45.842033]], pop: 41
# steps: 950, reward: [[45.835686]], pop: 41
# steps: 960, reward: [[45.889668]], pop: 41
# steps: 970, reward: [[45.9207]], pop: 41
# steps: 980, reward: [[45.911648]], pop: 41
# steps: 990, reward: [[45.877686]], pop: 41
# steps: 1000, reward: [[45.844837]], pop: 41
# =============episode done=============
# episode: 9, y_pred: [[41.62583]], score: [[45.844837]]
# =======================================
# steps: 10, reward: [[42.823788]], pop: 42
# steps: 20, reward: [[43.037056]], pop: 42
# steps: 30, reward: [[43.149582]], pop: 42
# steps: 40, reward: [[43.093487]], pop: 42
# steps: 50, reward: [[43.163597]], pop: 42
# steps: 60, reward: [[43.099384]], pop: 42
# steps: 70, reward: [[43.118164]], pop: 42
# steps: 80, reward: [[43.139454]], pop: 42
# steps: 90, reward: [[43.25073]], pop: 42
# steps: 100, reward: [[43.28639]], pop: 42
# steps: 110, reward: [[43.31521]], pop: 42
# steps: 120, reward: [[43.4156]], pop: 42
# steps: 130, reward: [[43.36106]], pop: 42
# steps: 140, reward: [[43.2938]], pop: 42
# steps: 150, reward: [[43.312294]], pop: 42
# steps: 160, reward: [[43.444218]], pop: 42
# steps: 170, reward: [[43.467476]], pop: 42
# steps: 180, reward: [[43.583656]], pop: 42
# steps: 190, reward: [[43.645203]], pop: 42
# steps: 200, reward: [[43.838806]], pop: 42
# steps: 210, reward: [[43.969795]], pop: 42
# steps: 220, reward: [[44.168964]], pop: 42
# steps: 230, reward: [[44.35919]], pop: 42
# steps: 240, reward: [[44.49263]], pop: 42
# steps: 250, reward: [[44.531086]], pop: 42
# steps: 260, reward: [[44.59669]], pop: 42
# steps: 270, reward: [[44.67957]], pop: 42
# steps: 280, reward: [[44.70135]], pop: 42
# steps: 290, reward: [[44.802074]], pop: 42
# steps: 300, reward: [[44.77364]], pop: 42
# steps: 310, reward: [[44.83061]], pop: 42
# steps: 320, reward: [[44.80982]], pop: 42
# steps: 330, reward: [[44.961094]], pop: 42
# steps: 340, reward: [[45.075336]], pop: 42
# steps: 350, reward: [[45.214935]], pop: 42
# steps: 360, reward: [[45.18113]], pop: 42
# steps: 370, reward: [[45.076572]], pop: 42
# steps: 380, reward: [[45.04776]], pop: 42
# steps: 390, reward: [[45.08519]], pop: 42
# steps: 400, reward: [[45.173946]], pop: 42
# steps: 410, reward: [[45.239723]], pop: 42
# steps: 420, reward: [[45.31177]], pop: 42
# steps: 430, reward: [[45.265263]], pop: 42
# steps: 440, reward: [[45.24516]], pop: 42
# steps: 450, reward: [[45.210114]], pop: 42
# steps: 460, reward: [[45.21782]], pop: 42
# steps: 470, reward: [[45.302162]], pop: 42
# steps: 480, reward: [[45.349846]], pop: 42
# steps: 490, reward: [[45.15735]], pop: 42
# steps: 500, reward: [[45.003876]], pop: 42
# steps: 510, reward: [[44.85232]], pop: 42
# steps: 520, reward: [[44.894764]], pop: 42
# steps: 530, reward: [[44.80815]], pop: 42
# steps: 540, reward: [[44.84968]], pop: 42
# steps: 550, reward: [[44.901634]], pop: 42
# steps: 560, reward: [[44.82146]], pop: 42
# steps: 570, reward: [[44.762768]], pop: 42
# steps: 580, reward: [[44.7402]], pop: 42
# steps: 590, reward: [[44.728394]], pop: 42
# steps: 600, reward: [[44.794357]], pop: 42
# steps: 610, reward: [[44.76438]], pop: 42
# steps: 620, reward: [[44.690582]], pop: 41
# steps: 630, reward: [[44.661087]], pop: 41
# steps: 640, reward: [[44.695915]], pop: 41
# steps: 650, reward: [[44.779606]], pop: 41
# steps: 660, reward: [[44.692932]], pop: 41
# steps: 670, reward: [[44.72159]], pop: 41
# steps: 680, reward: [[44.761787]], pop: 41
# steps: 690, reward: [[44.88349]], pop: 41
# steps: 700, reward: [[44.831818]], pop: 41
# steps: 710, reward: [[44.839592]], pop: 41
# steps: 720, reward: [[45.003967]], pop: 41
# steps: 730, reward: [[44.88613]], pop: 41
# steps: 740, reward: [[44.92123]], pop: 41
# steps: 750, reward: [[44.98268]], pop: 41
# steps: 760, reward: [[45.1212]], pop: 41
# steps: 770, reward: [[45.164806]], pop: 41
# steps: 780, reward: [[45.26513]], pop: 41
# steps: 790, reward: [[45.1795]], pop: 41
# steps: 800, reward: [[45.16208]], pop: 41
# steps: 810, reward: [[45.32461]], pop: 41
# steps: 820, reward: [[45.280987]], pop: 41
# steps: 830, reward: [[45.33026]], pop: 41
# steps: 840, reward: [[45.251274]], pop: 41
# steps: 850, reward: [[45.302895]], pop: 41
# steps: 860, reward: [[45.27159]], pop: 41
# steps: 870, reward: [[45.181828]], pop: 41
# steps: 880, reward: [[45.113083]], pop: 41
# steps: 890, reward: [[45.162594]], pop: 41
# steps: 900, reward: [[45.245777]], pop: 41
# steps: 910, reward: [[45.30049]], pop: 41
# steps: 920, reward: [[45.083183]], pop: 41
# steps: 930, reward: [[45.117683]], pop: 41
# steps: 940, reward: [[45.042217]], pop: 41
# steps: 950, reward: [[45.01958]], pop: 41
# steps: 960, reward: [[45.147728]], pop: 41
# steps: 970, reward: [[45.192543]], pop: 41
# steps: 980, reward: [[45.3674]], pop: 41
# steps: 990, reward: [[45.436275]], pop: 41
# steps: 1000, reward: [[45.406857]], pop: 41
# =============episode done=============
# episode: 10, y_pred: [[41.84596]], score: [[45.406857]]
# =======================================
# steps: 10, reward: [[42.57399]], pop: 42
# steps: 20, reward: [[42.764954]], pop: 42
# steps: 30, reward: [[42.936344]], pop: 42
# steps: 40, reward: [[42.91972]], pop: 42
# steps: 50, reward: [[43.07922]], pop: 42
# steps: 60, reward: [[43.077213]], pop: 42
# steps: 70, reward: [[43.12891]], pop: 42
# steps: 80, reward: [[43.24428]], pop: 42
# steps: 90, reward: [[43.256523]], pop: 42
# steps: 100, reward: [[43.39303]], pop: 42
# steps: 110, reward: [[43.369205]], pop: 42
# steps: 120, reward: [[43.387554]], pop: 42
# steps: 130, reward: [[43.61425]], pop: 42
# steps: 140, reward: [[43.78877]], pop: 42
# steps: 150, reward: [[44.05979]], pop: 42
# steps: 160, reward: [[44.29004]], pop: 42
# steps: 170, reward: [[44.513927]], pop: 42
# steps: 180, reward: [[44.629425]], pop: 42
# steps: 190, reward: [[44.774708]], pop: 42
# steps: 200, reward: [[44.720192]], pop: 42
# steps: 210, reward: [[44.596603]], pop: 42
# steps: 220, reward: [[44.657475]], pop: 42
# steps: 230, reward: [[44.71901]], pop: 42
# steps: 240, reward: [[44.758053]], pop: 42
# steps: 250, reward: [[44.729656]], pop: 42
# steps: 260, reward: [[44.715958]], pop: 42
# steps: 270, reward: [[44.687267]], pop: 42
# steps: 280, reward: [[44.717735]], pop: 42
# steps: 290, reward: [[44.62195]], pop: 42
# steps: 300, reward: [[44.67859]], pop: 42
# steps: 310, reward: [[44.68682]], pop: 42
# steps: 320, reward: [[44.62886]], pop: 42
# steps: 330, reward: [[44.67704]], pop: 42
# steps: 340, reward: [[44.642864]], pop: 42
# steps: 350, reward: [[44.690968]], pop: 42
# steps: 360, reward: [[44.642525]], pop: 42
# steps: 370, reward: [[44.62014]], pop: 42
# steps: 380, reward: [[44.586357]], pop: 42
# steps: 390, reward: [[44.582527]], pop: 42
# steps: 400, reward: [[44.6214]], pop: 42
# steps: 410, reward: [[44.70076]], pop: 42
# steps: 420, reward: [[44.663544]], pop: 42
# steps: 430, reward: [[44.76493]], pop: 42
# steps: 440, reward: [[44.8107]], pop: 42
# steps: 450, reward: [[44.819477]], pop: 42
# steps: 460, reward: [[44.696148]], pop: 42
# steps: 470, reward: [[44.78589]], pop: 42
# steps: 480, reward: [[44.72454]], pop: 42
# steps: 490, reward: [[44.725197]], pop: 42
# steps: 500, reward: [[44.804134]], pop: 42
# steps: 510, reward: [[44.730278]], pop: 42
# steps: 520, reward: [[44.800327]], pop: 42
# steps: 530, reward: [[45.022003]], pop: 42
# steps: 540, reward: [[45.02318]], pop: 42
# steps: 550, reward: [[45.01777]], pop: 42
# steps: 560, reward: [[44.962326]], pop: 42
# steps: 570, reward: [[44.93944]], pop: 42
# steps: 580, reward: [[45.0782]], pop: 42
# steps: 590, reward: [[44.984734]], pop: 42
# steps: 600, reward: [[44.913986]], pop: 42
# steps: 610, reward: [[45.001247]], pop: 42
# steps: 620, reward: [[45.12682]], pop: 42
# steps: 630, reward: [[45.16674]], pop: 42
# steps: 640, reward: [[45.26336]], pop: 42
# steps: 650, reward: [[45.28613]], pop: 42
# steps: 660, reward: [[45.2899]], pop: 42
# steps: 670, reward: [[45.329865]], pop: 42
# steps: 680, reward: [[45.423973]], pop: 42
# steps: 690, reward: [[45.50693]], pop: 42
# steps: 700, reward: [[45.466053]], pop: 42
# steps: 710, reward: [[45.55495]], pop: 42
# steps: 720, reward: [[45.570812]], pop: 42
# steps: 730, reward: [[45.590576]], pop: 42
# steps: 740, reward: [[45.60878]], pop: 42
# steps: 750, reward: [[45.494473]], pop: 42
# steps: 760, reward: [[45.38427]], pop: 42
# steps: 770, reward: [[45.360138]], pop: 42
# steps: 780, reward: [[45.415077]], pop: 42
# steps: 790, reward: [[45.432545]], pop: 42
# steps: 800, reward: [[45.428177]], pop: 41
# steps: 810, reward: [[45.39558]], pop: 41
# steps: 820, reward: [[45.477478]], pop: 41
# steps: 830, reward: [[45.524944]], pop: 41
# steps: 840, reward: [[45.675724]], pop: 42
# steps: 850, reward: [[45.74606]], pop: 42
# steps: 860, reward: [[45.871956]], pop: 42
# steps: 870, reward: [[45.93748]], pop: 42
# steps: 880, reward: [[45.86859]], pop: 42
# steps: 890, reward: [[45.936665]], pop: 42
# steps: 900, reward: [[46.092785]], pop: 42
# steps: 910, reward: [[46.196774]], pop: 42
# steps: 920, reward: [[46.36053]], pop: 42
# steps: 930, reward: [[46.60836]], pop: 42
# steps: 940, reward: [[46.702984]], pop: 42
# steps: 950, reward: [[47.0469]], pop: 42
# steps: 960, reward: [[47.048386]], pop: 42
# steps: 970, reward: [[47.1345]], pop: 42
# ...
# steps: 800, reward: [[46.11911]], pop: 41
# steps: 810, reward: [[46.288246]], pop: 41
# steps: 820, reward: [[46.25905]], pop: 41
# steps: 830, reward: [[46.343094]], pop: 41
# steps: 840, reward: [[46.30269]], pop: 41
# steps: 850, reward: [[46.467934]], pop: 41
# steps: 860, reward: [[46.648773]], pop: 41
# steps: 870, reward: [[46.87127]], pop: 41
# steps: 880, reward: [[46.908787]], pop: 41
# steps: 890, reward: [[46.921127]], pop: 41
# steps: 900, reward: [[46.97585]], pop: 41
# steps: 910, reward: [[46.9193]], pop: 41
# steps: 920, reward: [[46.95238]], pop: 41
# steps: 930, reward: [[47.045776]], pop: 41
# steps: 940, reward: [[47.091057]], pop: 42
# steps: 950, reward: [[47.037052]], pop: 41
# steps: 960, reward: [[47.03374]], pop: 41
# steps: 970, reward: [[46.947407]], pop: 41
# steps: 980, reward: [[46.98663]], pop: 41
# steps: 990, reward: [[46.932907]], pop: 41
# steps: 1000, reward: [[47.020287]], pop: 41
# =============episode done=============
# episode: 14, y_pred: [[41.95669]], score: [[47.020287]]
# =======================================
# steps: 10, reward: [[42.535744]], pop: 42
# steps: 20, reward: [[42.856678]], pop: 42
# steps: 30, reward: [[42.930145]], pop: 42
# steps: 40, reward: [[43.064445]], pop: 42
# steps: 50, reward: [[43.073963]], pop: 42
# steps: 60, reward: [[43.243023]], pop: 42
# steps: 70, reward: [[43.4428]], pop: 42
# steps: 80, reward: [[43.761845]], pop: 42
# steps: 90, reward: [[43.842236]], pop: 42
# steps: 100, reward: [[43.856525]], pop: 42
# steps: 110, reward: [[43.773]], pop: 42
# steps: 120, reward: [[43.74154]], pop: 42
# steps: 130, reward: [[43.830696]], pop: 42
# steps: 140, reward: [[43.831375]], pop: 42
# steps: 150, reward: [[44.123306]], pop: 42
# steps: 160, reward: [[44.114994]], pop: 42
# steps: 170, reward: [[44.0423]], pop: 42
# steps: 180, reward: [[44.13037]], pop: 42
# steps: 190, reward: [[44.314102]], pop: 42
# steps: 200, reward: [[44.31884]], pop: 42
# steps: 210, reward: [[44.252323]], pop: 42
# steps: 220, reward: [[44.258034]], pop: 42
# steps: 230, reward: [[44.34032]], pop: 42
# steps: 240, reward: [[44.407143]], pop: 42
# steps: 250, reward: [[44.303688]], pop: 42
# steps: 260, reward: [[44.55421]], pop: 42
# steps: 270, reward: [[44.58844]], pop: 42
# steps: 280, reward: [[44.67905]], pop: 42
# steps: 290, reward: [[44.633675]], pop: 42
# steps: 300, reward: [[44.813763]], pop: 42
# steps: 310, reward: [[44.894394]], pop: 42
# steps: 320, reward: [[45.085316]], pop: 42
# steps: 330, reward: [[45.148354]], pop: 42
# steps: 340, reward: [[45.335804]], pop: 42
# steps: 350, reward: [[45.401516]], pop: 42
# steps: 360, reward: [[45.600624]], pop: 42
# steps: 370, reward: [[45.67848]], pop: 42
# steps: 380, reward: [[45.673744]], pop: 42
# steps: 390, reward: [[45.65799]], pop: 42
# steps: 400, reward: [[45.577698]], pop: 42
# steps: 410, reward: [[45.45115]], pop: 42
# steps: 420, reward: [[45.53061]], pop: 42
# steps: 430, reward: [[45.562347]], pop: 42
# steps: 440, reward: [[45.57949]], pop: 42
# steps: 450, reward: [[45.608665]], pop: 42
# steps: 460, reward: [[45.727737]], pop: 42
# steps: 470, reward: [[45.902004]], pop: 42
# steps: 480, reward: [[45.96154]], pop: 42
# steps: 490, reward: [[46.21005]], pop: 42
# steps: 500, reward: [[46.24836]], pop: 42
# steps: 510, reward: [[46.206635]], pop: 42
# steps: 520, reward: [[46.16079]], pop: 42
# steps: 530, reward: [[46.1964]], pop: 42
# steps: 540, reward: [[46.26083]], pop: 42
# steps: 550, reward: [[46.311768]], pop: 42
# steps: 560, reward: [[46.484734]], pop: 42
# steps: 570, reward: [[46.53391]], pop: 42
# steps: 580, reward: [[46.70587]], pop: 42
# steps: 590, reward: [[46.759853]], pop: 42
# steps: 600, reward: [[46.798477]], pop: 42
# steps: 610, reward: [[46.8473]], pop: 42
# steps: 620, reward: [[46.801548]], pop: 42
# steps: 630, reward: [[46.821327]], pop: 42
# steps: 640, reward: [[46.85393]], pop: 42
# steps: 650, reward: [[46.970882]], pop: 42
# steps: 660, reward: [[46.882256]], pop: 42
# steps: 670, reward: [[46.90271]], pop: 42
# steps: 680, reward: [[46.772808]], pop: 42
# steps: 690, reward: [[46.68438]], pop: 42
# steps: 700, reward: [[46.60399]], pop: 42
# steps: 710, reward: [[46.690536]], pop: 42
# steps: 720, reward: [[46.641537]], pop: 42
# steps: 730, reward: [[46.47765]], pop: 42
# steps: 740, reward: [[46.496147]], pop: 42
# steps: 750, reward: [[46.43435]], pop: 42
# steps: 760, reward: [[46.451515]], pop: 42
# steps: 770, reward: [[46.4947]], pop: 42
# steps: 780, reward: [[46.537888]], pop: 42
# steps: 790, reward: [[46.544388]], pop: 42
# steps: 800, reward: [[46.54354]], pop: 42
# steps: 810, reward: [[46.688564]], pop: 42
# steps: 820, reward: [[46.731346]], pop: 42
# steps: 830, reward: [[46.749054]], pop: 42
# steps: 840, reward: [[46.706562]], pop: 42
# steps: 850, reward: [[46.797005]], pop: 42
# steps: 860, reward: [[46.71454]], pop: 42
# steps: 870, reward: [[46.720455]], pop: 42
# steps: 880, reward: [[46.766335]], pop: 42
# steps: 890, reward: [[46.94363]], pop: 42
# steps: 900, reward: [[46.94041]], pop: 42
# steps: 910, reward: [[46.99113]], pop: 42
# steps: 920, reward: [[46.984962]], pop: 42
# steps: 930, reward: [[47.079056]], pop: 42
# steps: 940, reward: [[47.10997]], pop: 42
# steps: 950, reward: [[47.04958]], pop: 42
# steps: 960, reward: [[47.192444]], pop: 42
# steps: 970, reward: [[47.446365]], pop: 42
# steps: 980, reward: [[47.512024]], pop: 42
# steps: 990, reward: [[47.60971]], pop: 42
# steps: 1000, reward: [[47.60093]], pop: 42
# =============episode done=============
# episode: 15, y_pred: [[42.679546]], score: [[47.60093]]
# =======================================
# steps: 10, reward: [[42.5885]], pop: 42
# steps: 20, reward: [[42.772404]], pop: 42
# steps: 30, reward: [[43.022804]], pop: 42
# steps: 40, reward: [[43.139442]], pop: 42
# steps: 50, reward: [[43.16574]], pop: 42
# steps: 60, reward: [[43.31675]], pop: 42
# steps: 70, reward: [[43.498825]], pop: 42
# steps: 80, reward: [[43.51698]], pop: 42
# steps: 90, reward: [[43.492203]], pop: 42
# steps: 100, reward: [[43.478928]], pop: 42
# steps: 110, reward: [[43.464626]], pop: 42
# steps: 120, reward: [[43.34821]], pop: 42
# steps: 130, reward: [[43.28666]], pop: 42
# steps: 140, reward: [[43.304657]], pop: 42
# steps: 150, reward: [[43.545284]], pop: 42
# steps: 160, reward: [[43.49926]], pop: 42
# steps: 170, reward: [[43.560143]], pop: 42
# steps: 180, reward: [[43.560017]], pop: 42
# steps: 190, reward: [[43.52094]], pop: 42
# steps: 200, reward: [[43.48935]], pop: 42
# steps: 210, reward: [[43.508217]], pop: 42
# steps: 220, reward: [[43.70613]], pop: 42
# steps: 230, reward: [[43.86378]], pop: 42
# steps: 240, reward: [[43.92332]], pop: 42
# steps: 250, reward: [[43.994553]], pop: 42
# steps: 260, reward: [[43.933327]], pop: 42
# steps: 270, reward: [[43.931034]], pop: 42
# steps: 280, reward: [[43.866367]], pop: 42
# steps: 290, reward: [[43.973602]], pop: 42
# steps: 300, reward: [[43.996784]], pop: 42
# steps: 310, reward: [[44.10878]], pop: 42
# steps: 320, reward: [[44.24304]], pop: 42
# steps: 330, reward: [[44.134506]], pop: 42
# steps: 340, reward: [[44.13129]], pop: 42
# steps: 350, reward: [[44.12592]], pop: 42
# steps: 360, reward: [[44.219772]], pop: 42
# steps: 370, reward: [[44.325733]], pop: 42
# steps: 380, reward: [[44.33059]], pop: 42
# steps: 390, reward: [[44.242443]], pop: 42
# steps: 400, reward: [[44.243195]], pop: 42
# steps: 410, reward: [[44.192158]], pop: 42
# steps: 420, reward: [[44.2485]], pop: 42
# steps: 430, reward: [[44.25162]], pop: 42
# steps: 440, reward: [[44.209496]], pop: 42
# steps: 450, reward: [[44.27282]], pop: 42
# steps: 460, reward: [[44.322628]], pop: 41
# steps: 470, reward: [[44.425617]], pop: 41
# steps: 480, reward: [[44.56669]], pop: 41
# steps: 490, reward: [[44.63184]], pop: 42
# steps: 500, reward: [[44.538124]], pop: 41
# steps: 510, reward: [[44.483047]], pop: 41
# steps: 520, reward: [[44.55265]], pop: 41
# steps: 530, reward: [[44.442898]], pop: 41
# steps: 540, reward: [[44.442238]], pop: 41
# steps: 550, reward: [[44.50151]], pop: 41
# steps: 560, reward: [[44.475574]], pop: 41
# steps: 570, reward: [[44.522728]], pop: 41
# steps: 580, reward: [[44.803783]], pop: 41
# steps: 590, reward: [[44.769222]], pop: 41
# steps: 600, reward: [[44.803375]], pop: 41
# steps: 610, reward: [[44.875404]], pop: 41
# steps: 620, reward: [[44.826595]], pop: 41
# steps: 630, reward: [[44.669098]], pop: 41
# steps: 640, reward: [[44.75487]], pop: 41
# steps: 650, reward: [[44.77687]], pop: 41
# steps: 660, reward: [[44.86661]], pop: 41
# steps: 670, reward: [[45.02061]], pop: 41
# steps: 680, reward: [[45.157295]], pop: 41
# steps: 690, reward: [[45.204903]], pop: 41
# steps: 700, reward: [[45.37685]], pop: 41
# steps: 710, reward: [[45.46977]], pop: 41
# steps: 720, reward: [[45.433876]], pop: 41
# steps: 730, reward: [[45.424305]], pop: 42
# steps: 740, reward: [[45.439785]], pop: 41
# steps: 750, reward: [[45.50165]], pop: 41
# steps: 760, reward: [[45.430534]], pop: 41
# steps: 770, reward: [[45.33153]], pop: 41
# steps: 780, reward: [[45.413956]], pop: 41
# steps: 790, reward: [[45.413097]], pop: 41
# steps: 800, reward: [[45.412403]], pop: 41
# steps: 810, reward: [[45.26313]], pop: 41
# steps: 820, reward: [[45.15504]], pop: 41
# steps: 830, reward: [[45.15808]], pop: 41
# steps: 840, reward: [[45.0916]], pop: 41
# steps: 850, reward: [[45.083035]], pop: 41
# steps: 860, reward: [[45.22592]], pop: 41
# steps: 870, reward: [[45.18198]], pop: 41
# steps: 880, reward: [[45.126797]], pop: 41
# steps: 890, reward: [[45.245598]], pop: 41
# steps: 900, reward: [[45.20126]], pop: 41
# steps: 910, reward: [[45.126]], pop: 41
# steps: 920, reward: [[45.012177]], pop: 41
# steps: 930, reward: [[44.895515]], pop: 41
# steps: 940, reward: [[44.82309]], pop: 41
# steps: 950, reward: [[44.819725]], pop: 41
# steps: 960, reward: [[44.795185]], pop: 41
# steps: 970, reward: [[44.83903]], pop: 41
# steps: 980, reward: [[44.82029]], pop: 41
# steps: 990, reward: [[44.813923]], pop: 41
# steps: 1000, reward: [[44.882523]], pop: 41
# =============episode done=============
# episode: 16, y_pred: [[41.946537]], score: [[44.882523]]
# =======================================
# steps: 10, reward: [[42.58778]], pop: 42
# steps: 20, reward: [[42.89399]], pop: 42
# steps: 30, reward: [[42.932777]], pop: 42
# steps: 40, reward: [[42.915154]], pop: 42
# steps: 50, reward: [[43.1256]], pop: 42
# steps: 60, reward: [[43.36538]], pop: 42
# steps: 70, reward: [[43.436474]], pop: 42
# steps: 80, reward: [[43.503605]], pop: 42
# steps: 90, reward: [[43.510445]], pop: 41
# steps: 100, reward: [[43.538437]], pop: 41
# steps: 110, reward: [[43.534447]], pop: 41
# steps: 120, reward: [[43.432407]], pop: 41
# steps: 130, reward: [[43.37203]], pop: 41
# steps: 140, reward: [[43.54109]], pop: 41
# steps: 150, reward: [[43.61666]], pop: 41
# steps: 160, reward: [[43.63901]], pop: 41
# steps: 170, reward: [[43.537186]], pop: 41
# steps: 180, reward: [[43.55906]], pop: 41
# steps: 190, reward: [[43.52096]], pop: 41
# steps: 200, reward: [[43.550606]], pop: 41
# steps: 210, reward: [[43.594994]], pop: 41
# steps: 220, reward: [[43.585327]], pop: 41
# steps: 230, reward: [[43.738808]], pop: 41
# steps: 240, reward: [[43.841045]], pop: 41
# steps: 250, reward: [[43.897346]], pop: 41
# steps: 260, reward: [[43.843292]], pop: 41
# steps: 270, reward: [[43.820747]], pop: 41
# steps: 280, reward: [[43.841465]], pop: 41
# steps: 290, reward: [[43.821575]], pop: 41
# steps: 300, reward: [[43.930912]], pop: 41
# steps: 310, reward: [[43.938717]], pop: 41
# steps: 320, reward: [[43.991924]], pop: 41
# steps: 330, reward: [[43.927013]], pop: 41
# steps: 340, reward: [[43.834393]], pop: 41
# steps: 350, reward: [[43.908733]], pop: 41
# steps: 360, reward: [[44.031246]], pop: 41
# steps: 370, reward: [[43.950676]], pop: 41
# steps: 380, reward: [[43.97139]], pop: 41
# steps: 390, reward: [[44.058636]], pop: 41
# steps: 400, reward: [[44.2198]], pop: 41
# steps: 410, reward: [[44.18258]], pop: 41
# steps: 420, reward: [[44.22794]], pop: 41
# steps: 430, reward: [[44.34371]], pop: 41
# steps: 440, reward: [[44.304806]], pop: 41
# steps: 450, reward: [[44.30895]], pop: 41
# steps: 460, reward: [[44.557007]], pop: 41
# steps: 470, reward: [[44.620193]], pop: 41
# steps: 480, reward: [[44.719822]], pop: 41
# steps: 490, reward: [[44.770863]], pop: 41
# steps: 500, reward: [[44.77864]], pop: 41
# steps: 510, reward: [[44.811592]], pop: 41
# steps: 520, reward: [[44.865826]], pop: 41
# steps: 530, reward: [[45.071964]], pop: 41
# steps: 540, reward: [[45.1403]], pop: 41
# steps: 550, reward: [[45.31484]], pop: 41
# steps: 560, reward: [[45.51639]], pop: 41
# steps: 570, reward: [[45.631332]], pop: 41
# steps: 580, reward: [[45.72834]], pop: 41
# steps: 590, reward: [[45.786877]], pop: 41
# steps: 600, reward: [[45.83316]], pop: 41
# steps: 610, reward: [[45.774113]], pop: 41
# steps: 620, reward: [[45.8411]], pop: 41
# steps: 630, reward: [[45.814903]], pop: 41
# steps: 640, reward: [[45.87505]], pop: 41
# steps: 650, reward: [[45.837692]], pop: 41
# steps: 660, reward: [[45.800297]], pop: 41
# steps: 670, reward: [[45.803005]], pop: 41
# steps: 680, reward: [[45.831516]], pop: 41
# steps: 690, reward: [[45.89376]], pop: 42
# steps: 700, reward: [[45.92801]], pop: 42
# steps: 710, reward: [[45.911037]], pop: 41
# steps: 720, reward: [[45.895924]], pop: 41
# steps: 730, reward: [[45.918]], pop: 41
# steps: 740, reward: [[45.968582]], pop: 41
# steps: 750, reward: [[45.900623]], pop: 41
# steps: 760, reward: [[45.903862]], pop: 41
# steps: 770, reward: [[45.96437]], pop: 41
# steps: 780, reward: [[45.915516]], pop: 41
# steps: 790, reward: [[45.976757]], pop: 41
# steps: 800, reward: [[45.866367]], pop: 41
# steps: 810, reward: [[45.807755]], pop: 41
# steps: 820, reward: [[45.798786]], pop: 41
# steps: 830, reward: [[45.73978]], pop: 41
# steps: 840, reward: [[45.84706]], pop: 41
# steps: 850, reward: [[45.832737]], pop: 41
# steps: 860, reward: [[45.743416]], pop: 41
# steps: 870, reward: [[45.68733]], pop: 41
# steps: 880, reward: [[45.7646]], pop: 41
# steps: 890, reward: [[45.846]], pop: 41
# steps: 900, reward: [[45.82934]], pop: 41
# steps: 910, reward: [[45.779697]], pop: 41
# steps: 920, reward: [[45.847992]], pop: 41
# steps: 930, reward: [[45.757954]], pop: 41
# steps: 940, reward: [[45.70601]], pop: 41
# steps: 950, reward: [[45.54938]], pop: 41
# steps: 960, reward: [[45.47281]], pop: 41
# steps: 970, reward: [[45.59793]], pop: 41
# steps: 980, reward: [[45.538605]], pop: 41
# steps: 990, reward: [[45.644302]], pop: 41
# steps: 1000, reward: [[45.681713]], pop: 41
# =============episode done=============
# episode: 17, y_pred: [[41.661762]], score: [[45.681713]]
# =======================================
# steps: 10, reward: [[42.61539]], pop: 42
# steps: 20, reward: [[42.687897]], pop: 42
# steps: 30, reward: [[42.813877]], pop: 42
# steps: 40, reward: [[42.931534]], pop: 42
# steps: 50, reward: [[42.871532]], pop: 42
# steps: 60, reward: [[43.04616]], pop: 42
# steps: 70, reward: [[43.20706]], pop: 42
# steps: 80, reward: [[43.34877]], pop: 42
# steps: 90, reward: [[43.38729]], pop: 42
# steps: 100, reward: [[43.591793]], pop: 42
# steps: 110, reward: [[43.545048]], pop: 42
# steps: 120, reward: [[43.837143]], pop: 42
# steps: 130, reward: [[44.036694]], pop: 42
# steps: 140, reward: [[44.27962]], pop: 42
# steps: 150, reward: [[44.132572]], pop: 42
# steps: 160, reward: [[44.164635]], pop: 42
# steps: 170, reward: [[44.11114]], pop: 42
# steps: 180, reward: [[44.10789]], pop: 42
# steps: 190, reward: [[44.190304]], pop: 42
# steps: 200, reward: [[44.23671]], pop: 42
# steps: 210, reward: [[44.321957]], pop: 42
# steps: 220, reward: [[44.32482]], pop: 42
# steps: 230, reward: [[44.332138]], pop: 42
# steps: 240, reward: [[44.323883]], pop: 42
# steps: 250, reward: [[44.293915]], pop: 42
# steps: 260, reward: [[44.33623]], pop: 42
# steps: 270, reward: [[44.46634]], pop: 42
# steps: 280, reward: [[44.513775]], pop: 42
# steps: 290, reward: [[44.59217]], pop: 42
# steps: 300, reward: [[44.64456]], pop: 42
# steps: 310, reward: [[44.56473]], pop: 42
# steps: 320, reward: [[44.71084]], pop: 42
# steps: 330, reward: [[44.963055]], pop: 42
# steps: 340, reward: [[45.161217]], pop: 42
# steps: 350, reward: [[45.24827]], pop: 42
# steps: 360, reward: [[45.30908]], pop: 42
# steps: 370, reward: [[45.27361]], pop: 42
# steps: 380, reward: [[45.325565]], pop: 42
# steps: 390, reward: [[45.327835]], pop: 42
# steps: 400, reward: [[45.31623]], pop: 42
# steps: 410, reward: [[45.322437]], pop: 42
# steps: 420, reward: [[45.2408]], pop: 42
# steps: 430, reward: [[44.948326]], pop: 42

# %%
plt.plot(np.array(pop_hist).reshape(99))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\code\activ\programs\dqn\tf_dqn.ipynb 셀 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/code/activ/programs/dqn/tf_dqn.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> print(pop_hist)
#
# NameError: name 'pop_hist' is not defined

# %%
plt.plot(np.array(sc_hist).reshape(99))
plt.show()
